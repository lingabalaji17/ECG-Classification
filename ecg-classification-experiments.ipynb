# %%
import pandas as pd
import numpy as np
import os
import wfdb
import ast

import tensorflow as tf
from tensorflow import keras
#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # Loading Data

# %%
'''function to load the data from the saved file path for different experiments. 
    Saved Data for future use and for conducting experiments as extracting data is resource intensive'''
def load_data(filepath, type, x_key='x', y_key='y'):
    # Load X_test and Y_test
    data = np.load(filepath)
    x = data[x_key]
    y = data[y_key]

    print (f"Shape of X-{type} and Y_{type} : {x.shape},  {y.shape}")
    return x, y

# %%
'''function to create dataset from the numpy array'''
def create_dataset(x, y, batch_size=256):
    dataset_X = tf.data.Dataset.from_tensor_slices(x)
    dataset_Y = tf.data.Dataset.from_tensor_slices(y)
    dataset =  tf.data.Dataset.zip((dataset_X, dataset_Y))

    ds = dataset.batch(batch_size, drop_remainder=True)

    for batch in ds.take(1):
        print([f"Shape of Batched Dataset {arr.numpy().shape}" for arr in batch])
    
    return ds

# %% [markdown]
# # Utils functions for Building and Evaluating Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, MultiHeadAttention, Dense, Flatten, Input,GlobalAveragePooling1D, BatchNormalization,MaxPooling1D,Attention,LayerNormalization, Dropout,Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_recall_fscore_support, roc_auc_score

def evaluate_model(model, Y_test, x_test=None):
    # Predict labels for the test set
   # Get the predicted probabilities
    if(x_test is None):
        x_test = X_test
        
    Y_pred_prob = model.predict(x_test)

    # Convert the predicted probabilities to class labels
    Y_pred = np.argmax(Y_pred_prob, axis=1)

    # Calculate evaluation metrics
    confusion = confusion_matrix(Y_test, Y_pred)
    report = classification_report(Y_test, Y_pred)
    accuracy = accuracy_score(Y_test, Y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(Y_test, Y_pred, average='weighted')
    #auc = roc_auc_score(Y_test, Y_pred)
    #num_parameters = model.count_params()  # Replace with the appropriate method to count model parameters

    # Create a dictionary of evaluation metrics
    evaluation = {
        'confusion_matrix': confusion,
        'classification_report': report,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        #'auc': auc,
        #'num_parameters': num_parameters
    }

    return evaluation

# %%
import seaborn as sns

def plot_confusion_matrix(confusion):
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion, annot=True, cmap='Blues', fmt='g')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

def plot_classification_report(report):
    # Extract precision, recall, and F1-score from the report
    lines = report.split('\n')[2:-5]
    classes = []
    precision = []
    recall = []
    f1_score = []
    for line in lines:
        row = line.split()
        classes.append(row[0])
        precision.append(float(row[1]))
        recall.append(float(row[2]))
        f1_score.append(float(row[3]))

    # Plot precision, recall, and F1-score
    plt.figure(figsize=(10, 4))
    plt.bar(classes, precision, label='Precision')
    plt.bar(classes, recall, label='Recall')
    plt.bar(classes, f1_score, label='F1-Score')
    plt.xlabel('Classes')
    plt.ylabel('Scores')
    plt.title('Classification Report')
    plt.legend()
    plt.show()
    
def plot_loss(history):
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def plot_roc_curves(Y_test, Y_scores):
    # Compute the number of classes
    num_classes = len(np.unique(Y_test))

    # Compute the fpr, tpr, and roc_auc for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(Y_test == i, Y_scores[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curves for each class
    plt.figure(figsize=(8, 6))

    colors = cycle(['blue', 'red', 'green', 'orange', 'purple'])
    classes = [f'Class {i}' for i in range(num_classes)]

    for i, color in zip(range(num_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of {classes[i]} (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc='lower right')
    plt.show()

# %%
def display_output(model, history, x_test=None):

    if(x_test is None):
        x_test = X_test
    Y_pred = model.predict(x_test)
    # Evaluate the model
    evaluation = evaluate_model(model, Y_test, x_test)
    
    #plot the history loss
    plot_loss(history)
    
    # Access individual evaluation metrics
    confusion = evaluation['confusion_matrix']
    report = evaluation['classification_report']
    print(f"Accuracy of the Model is  {evaluation['accuracy']}")
    print (f"Precision of the Model is {evaluation['precision']}")
    print (f"Recall of the Model is {evaluation['recall']}")
    print(f"F1 Score of the Model is {evaluation['f1_score']}")
    #auc = evaluation['auc']
    #num_parameters = evaluation['num_parameters']

    #plot the confusion matrix and classification report
    plot_confusion_matrix(confusion)
    plot_classification_report(report)

    plot_roc_curves(Y_test, Y_pred)

# %%
def get_optimizer(optimizer, learning_rate):
    if(optimizer=="adam"):
        return tf.keras.optimizers.Adam(learning_rate)
    elif (optimizer=="sgd"):
        return tf.keras.optimizers.SGD(learning_rate)
    elif (optimizer=="rmsprop"):
        return tf.keras.optimizers.RMSprop(learning_rate)
    elif (optimizer=="nadam"):
        return tf.keras.optimizers.Nadam(learning_rate)
    elif (optimizer=="adagrad"):
        return tf.keras.optimizers.Adagrad(learning_rate)
    else:
        return tf.keras.optimizers.Adam(learning_rate)

def get_callbacks(name):
    model_output = f'{name}.h5'
    
    return  [keras.callbacks.ModelCheckpoint(model_output, save_best_only=True, monitor="val_loss"),
                keras.callbacks.ReduceLROnPlateau( monitor="val_loss", factor=0.2, patience=3, min_lr=0.0001),
                keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
    
def compile_and_fit(model, name,optimizer, epochs=30, batch_size=256, learning_rate=0.01,shuffle=False):
    optimizer = get_optimizer(optimizer, learning_rate)

    model.compile(optimizer=optimizer,
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=['accuracy'])
    model.summary()
    history = model.fit(train_ds,
                      epochs=epochs,
                      validation_data=val_ds,
                      callbacks=get_callbacks(name),
                      verbose=1, batch_size=batch_size,shuffle=shuffle)
    return history

# %% [markdown]
# # Experiment 1 : (Raw Signal) --> CNN Model

# %%
X_train, Y_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
#HYPER_PARAMETERS
BATCH_SIZE = 256
num_classes = 5
LEARNING_RATE = 0.01
input_shape = X_train.shape[1:]
activation_fn = 'relu'

# %%
# Create the Conv1D model
def create_conv1d_model(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, activation='relu', input_shape=input_shape, kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Conv1D(256, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv1D(256, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Conv1D(128, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Conv1D(128, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(GlobalAveragePooling1D())
    model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
conv1d_model = create_conv1d_model(input_shape)

# %%
history = compile_and_fit(conv1d_model,"expt1_conv1d_model",optimizer='adam',epochs=20,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 256)           768256
#
#  batch_normalization (BatchN  (None, 10, 256)          1024
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            196864
#
#  batch_normalization_1 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 8, 256)           0
#  )
#
#  dropout (Dropout)           (None, 8, 256)            0
#
#  conv1d_2 (Conv1D)           (None, 6, 256)            196864
#
#  batch_normalization_2 (Batc  (None, 6, 256)           1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 6, 256)            0
#
#  conv1d_3 (Conv1D)           (None, 4, 128)            98432
#
#  batch_normalization_3 (Batc  (None, 4, 128)           512
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 2, 128)            49280
#
#  batch_normalization_4 (Batc  (None, 2, 128)           512
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1024)              132096
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 1,451,013
# Trainable params: 1,448,965
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/20
# 44/44 [==============================] - 13s 226ms/step - loss: 11.1255 - accuracy: 0.5437 - val_loss: 7.6607 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/20
# 44/44 [==============================] - 9s 206ms/step - loss: 5.6839 - accuracy: 0.5693 - val_loss: 4.4089 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/20
# 44/44 [==============================] - 9s 205ms/step - loss: 3.2701 - accuracy: 0.5763 - val_loss: 2.9498 - val_accuracy: 0.1341 - lr: 0.0010
# Epoch 4/20
# 44/44 [==============================] - 9s 212ms/step - loss: 2.2231 - accuracy: 0.5746 - val_loss: 2.4009 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 5/20
# 44/44 [==============================] - 9s 203ms/step - loss: 1.7567 - accuracy: 0.5779 - val_loss: 2.3254 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 6/20
# 44/44 [==============================] - 9s 206ms/step - loss: 1.5563 - accuracy: 0.5775 - val_loss: 2.1342 - val_accuracy: 0.1341 - lr: 0.0010
# Epoch 7/20
# 44/44 [==============================] - 9s 214ms/step - loss: 1.4829 - accuracy: 0.5735 - val_loss: 9.9434 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 8/20
# 44/44 [==============================] - 9s 204ms/step - loss: 1.4270 - accuracy: 0.5742 - val_loss: 6.9405 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 9/20
# 44/44 [==============================] - 9s 201ms/step - loss: 1.3727 - accuracy: 0.5775 - val_loss: 9.1390 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 10/20
# 44/44 [==============================] - 9s 212ms/step - loss: 1.3251 - accuracy: 0.5821 - val_loss: 5.5882 - val_accuracy: 0.1341 - lr: 2.0000e-04
# Epoch 11/20
# 44/44 [==============================] - 9s 205ms/step - loss: 1.2753 - accuracy: 0.5867 - val_loss: 2.5650 - val_accuracy: 0.1341 - lr: 2.0000e-04
# Epoch 12/20
# 44/44 [==============================] - 9s 200ms/step - loss: 1.2456 - accuracy: 0.5898 - val_loss: 3.0005 - val_accuracy: 0.1344 - lr: 2.0000e-04
# Epoch 13/20
# 44/44 [==============================] - 9s 216ms/step - loss: 1.2234 - accuracy: 0.5932 - val_loss: 5.0729 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 14/20
# 44/44 [==============================] - 9s 203ms/step - loss: 1.2068 - accuracy: 0.5969 - val_loss: 6.2580 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 15/20
# 44/44 [==============================] - 9s 208ms/step - loss: 1.1874 - accuracy: 0.6024 - val_loss: 6.3327 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 16/20
# 44/44 [==============================] - 9s 209ms/step - loss: 1.1714 - accuracy: 0.6061 - val_loss: 1.6851 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 17/20
# 44/44 [==============================] - 10s 218ms/step - loss: 1.1568 - accuracy: 0.6109 - val_loss: 10.6202 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 18/20
# 44/44 [==============================] - 9s 206ms/step - loss: 1.1500 - accuracy: 0.6149 - val_loss: 29.9501 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 19/20
# 44/44 [==============================] - 9s 205ms/step - loss: 1.1352 - accuracy: 0.6188 - val_loss: 34.1014 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 20/20
# 44/44 [==============================] - 9s 211ms/step - loss: 1.1104 - accuracy: 0.6271 - val_loss: 17.7600 - val_accuracy: 0.1344 - lr: 1.0000e-04

# %%
display_output(conv1d_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.13832335329341316
# Precision of the Model is 0.019133350066334397
# Recall of the Model is 0.13832335329341316
# F1 Score of the Model is 0.03361672236799415

# %% [markdown]
# # Experiment 2: LSTM Model

# %%
# Create the LSTM model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(LSTM(64,return_sequences=True,))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(LSTM(64,return_sequences=True,))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='sigmoid'))
    return model

# %%
lstm_model = create_lstm_model(input_shape)

# %%
history = compile_and_fit(lstm_model,"expt2_lstm_model",optimizer='adam',epochs=25,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 64)            272640
#
#  batch_normalization_5 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 12, 64)            0
#
#  lstm_1 (LSTM)               (None, 12, 64)            33024
#
#  batch_normalization_6 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 12, 64)            0
#
#  lstm_2 (LSTM)               (None, 12, 64)            33024
#
#  batch_normalization_7 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 12, 64)            0
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense_2 (Dense)             (None, 5)                 3845
#
# =================================================================
# Total params: 343,301
# Trainable params: 342,917
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/25
# 44/44 [==============================] - 12s 146ms/step - loss: 1.7412 - accuracy: 0.4260 - val_loss: 1.5690 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.5382 - accuracy: 0.4626 - val_loss: 1.5674 - val_accuracy: 0.1162 - lr: 0.0010
# Epoch 3/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.4630 - accuracy: 0.4797 - val_loss: 1.5272 - val_accuracy: 0.1162 - lr: 0.0010
# Epoch 4/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.4044 - accuracy: 0.5079 - val_loss: 1.4951 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 5s 115ms/step - loss: 1.3718 - accuracy: 0.5191 - val_loss: 1.4066 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 5s 116ms/step - loss: 1.3687 - accuracy: 0.5273 - val_loss: 1.4078 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 5s 113ms/step - loss: 1.3495 - accuracy: 0.5312 - val_loss: 1.4081 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.3472 - accuracy: 0.5367 - val_loss: 1.4072 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.3320 - accuracy: 0.5452 - val_loss: 1.3346 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 10/25
# 44/44 [==============================] - 5s 114ms/step - loss: 1.3096 - accuracy: 0.5498 - val_loss: 1.3349 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 11/25
# 44/44 [==============================] - 5s 115ms/step - loss: 1.3131 - accuracy: 0.5506 - val_loss: 1.3481 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 12/25
# 44/44 [==============================] - 5s 121ms/step - loss: 1.3072 - accuracy: 0.5510 - val_loss: 1.3203 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 13/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.3142 - accuracy: 0.5495 - val_loss: 1.3133 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 14/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.3096 - accuracy: 0.5519 - val_loss: 1.2988 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 15/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.3098 - accuracy: 0.5518 - val_loss: 1.2979 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 16/25
# 44/44 [==============================] - 5s 124ms/step - loss: 1.3036 - accuracy: 0.5525 - val_loss: 1.3417 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 17/25
# 44/44 [==============================] - 5s 119ms/step - loss: 1.3092 - accuracy: 0.5524 - val_loss: 1.3049 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 18/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.3021 - accuracy: 0.5526 - val_loss: 1.3077 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 19/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.3005 - accuracy: 0.5536 - val_loss: 1.3107 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 20/25
# 44/44 [==============================] - 6s 126ms/step - loss: 1.2971 - accuracy: 0.5544 - val_loss: 1.3153 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 21/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.2953 - accuracy: 0.5543 - val_loss: 1.3144 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 22/25
# 44/44 [==============================] - 5s 116ms/step - loss: 1.2966 - accuracy: 0.5539 - val_loss: 1.3082 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 23/25
# 44/44 [==============================] - 5s 119ms/step - loss: 1.2996 - accuracy: 0.5531 - val_loss: 1.3138 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 24/25
# 44/44 [==============================] - 6s 126ms/step - loss: 1.3009 - accuracy: 0.5546 - val_loss: 1.3135 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 25/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.2932 - accuracy: 0.5543 - val_loss: 1.3180 - val_accuracy: 0.5544 - lr: 1.0000e-04

# %%
display_output(lstm_model, history)
# Out:
# 53/53 [==============================] - 2s 11ms/step
# 53/53 [==============================] - 1s 11ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5401197604790419
# Precision of the Model is 0.2917293556599376
# Recall of the Model is 0.5401197604790419
# F1 Score of the Model is 0.3788398320000745

# %% [markdown]
# # Experiment 3: 1D CNN MHA (Multi Head Attention) model

# %%
def create_conv1d_mha_model(input_shape, regularizer=0.01):
    inputs = Input(shape=input_shape)
    
    # Convolutional layers
    conv1 = Conv1D(32, 1, activation='relu')(inputs)
    batch_norm1 =  BatchNormalization()(conv1)
    conv2 = Conv1D(64, 1, activation='relu')(batch_norm1)
    batch_norm2 =  BatchNormalization()(conv2)
    max_pooling1 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm2)
    dropout1 = Dropout(0.2)(max_pooling1)
    conv3 = Conv1D(128, 1, activation='relu')(dropout1)
    batch_norm3 =  BatchNormalization()(conv3)
    dropout2 = Dropout(0.3)(batch_norm3)
    conv4 = Conv1D(128, 1, activation='relu')(dropout2)
    batch_norm4 =  BatchNormalization()(conv4)
    max_pooling2 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm4)
    conv5 = Conv1D(512, 1, activation='relu')(max_pooling2)
    batch_norm5 =  BatchNormalization()(conv5)
    conv6 = Conv1D(512, 1, activation='relu')(batch_norm5)
    # Multi-head attention
    attention = MultiHeadAttention(num_heads=5, key_dim=3)(conv6, conv6)
    attention = LayerNormalization(epsilon=1e-6)(attention)
    
    # Concatenate attention output and conv3
    concat = Concatenate()([conv6, attention])
    
    # Global average pooling
    pool = tf.keras.layers.GlobalAveragePooling1D()(concat)
    
    dropout3 = Dropout(0.3)(pool)
    
     # Dense layers
    dense1 = Dense(256, activation='relu')(dropout3)
    dropout4 = Dropout(0.5)(dense1)
    dense2 = Dense(128, activation='relu')(dropout4)
    # Dense layer
    dense = Dense(num_classes, activation='softmax',
                  kernel_regularizer=regularizers.l2(regularizer))(dense2) 
    
    # Create model
    model = Model(inputs=inputs, outputs=dense)
    
    return model

# %%
conv1d_mha_model= create_conv1d_mha_model(input_shape)

# %%
history = compile_and_fit(conv1d_mha_model,"expt3_cnn_mha_model",optimizer='adam',epochs=25,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 12, 1000)]   0           []
#
#  conv1d_5 (Conv1D)              (None, 12, 32)       32032       ['input_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 12, 32)      128         ['conv1d_5[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 12, 64)       2112        ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 12, 64)      256         ['conv1d_6[0][0]']
#  rmalization)
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 12, 64)      0           ['batch_normalization_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 12, 64)       0           ['max_pooling1d_3[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 12, 128)      8320        ['dropout_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 12, 128)     512         ['conv1d_7[0][0]']
#  ormalization)
#
#  dropout_6 (Dropout)            (None, 12, 128)      0           ['batch_normalization_10[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 12, 128)      16512       ['dropout_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 12, 128)     512         ['conv1d_8[0][0]']
#  ormalization)
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 12, 128)     0           ['batch_normalization_11[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 12, 512)      66048       ['max_pooling1d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 12, 512)     2048        ['conv1d_9[0][0]']
#  ormalization)
#
#  conv1d_10 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_12[0][0]']
#
#  multi_head_attention (MultiHea  (None, 12, 512)     31277       ['conv1d_10[0][0]',
#  dAttention)                                                      'conv1d_10[0][0]']
#
#  layer_normalization (LayerNorm  (None, 12, 512)     1024        ['multi_head_attention[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 12, 1024)     0           ['conv1d_10[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 1024)        0           ['concatenate[0][0]']
#  obalAveragePooling1D)
#
#  dropout_7 (Dropout)            (None, 1024)         0           ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 256)          262400      ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['dropout_8[0][0]']
#
#  dense_5 (Dense)                (None, 5)            645         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 719,378
# Trainable params: 717,650
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/25
# 44/44 [==============================] - 17s 290ms/step - loss: 1.4165 - accuracy: 0.5392 - val_loss: 1.3886 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/25
# 44/44 [==============================] - 12s 268ms/step - loss: 1.3142 - accuracy: 0.5762 - val_loss: 1.3904 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/25
# 44/44 [==============================] - 12s 273ms/step - loss: 1.2945 - accuracy: 0.5737 - val_loss: 1.3689 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/25
# 44/44 [==============================] - 12s 266ms/step - loss: 1.2713 - accuracy: 0.5771 - val_loss: 1.3948 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.2595 - accuracy: 0.5756 - val_loss: 1.3671 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.2361 - accuracy: 0.5769 - val_loss: 1.3835 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 12s 269ms/step - loss: 1.2247 - accuracy: 0.5783 - val_loss: 1.3696 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 12s 270ms/step - loss: 1.2092 - accuracy: 0.5803 - val_loss: 1.3764 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 12s 280ms/step - loss: 1.1871 - accuracy: 0.5819 - val_loss: 1.3403 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 10/25
# 44/44 [==============================] - 12s 271ms/step - loss: 1.1823 - accuracy: 0.5826 - val_loss: 1.3541 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 11/25
# 44/44 [==============================] - 12s 273ms/step - loss: 1.1747 - accuracy: 0.5847 - val_loss: 1.3361 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 12/25
# 44/44 [==============================] - 12s 278ms/step - loss: 1.1701 - accuracy: 0.5849 - val_loss: 1.3846 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 13/25
# 44/44 [==============================] - 12s 272ms/step - loss: 1.1669 - accuracy: 0.5830 - val_loss: 1.3248 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 14/25
# 44/44 [==============================] - 12s 269ms/step - loss: 1.1637 - accuracy: 0.5843 - val_loss: 1.3622 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 15/25
# 44/44 [==============================] - 12s 268ms/step - loss: 1.1590 - accuracy: 0.5866 - val_loss: 1.5855 - val_accuracy: 0.1579 - lr: 2.0000e-04
# Epoch 16/25
# 44/44 [==============================] - 12s 268ms/step - loss: 1.1579 - accuracy: 0.5842 - val_loss: 1.5169 - val_accuracy: 0.5534 - lr: 2.0000e-04
# Epoch 17/25
# 44/44 [==============================] - 11s 261ms/step - loss: 1.1490 - accuracy: 0.5877 - val_loss: 1.3482 - val_accuracy: 0.5550 - lr: 1.0000e-04
# Epoch 18/25
# 44/44 [==============================] - 12s 266ms/step - loss: 1.1476 - accuracy: 0.5890 - val_loss: 1.3742 - val_accuracy: 0.5557 - lr: 1.0000e-04
# Epoch 19/25
# 44/44 [==============================] - 12s 267ms/step - loss: 1.1477 - accuracy: 0.5873 - val_loss: 1.6172 - val_accuracy: 0.1660 - lr: 1.0000e-04
# Epoch 20/25
# 44/44 [==============================] - 12s 272ms/step - loss: 1.1430 - accuracy: 0.5880 - val_loss: 2.7739 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 21/25
# 44/44 [==============================] - 12s 263ms/step - loss: 1.1429 - accuracy: 0.5875 - val_loss: 1.3307 - val_accuracy: 0.5599 - lr: 1.0000e-04
# Epoch 22/25
# 44/44 [==============================] - 12s 271ms/step - loss: 1.1356 - accuracy: 0.5898 - val_loss: 2.3195 - val_accuracy: 0.1322 - lr: 1.0000e-04
# Epoch 23/25
# 44/44 [==============================] - 12s 273ms/step - loss: 1.1399 - accuracy: 0.5866 - val_loss: 1.5377 - val_accuracy: 0.4251 - lr: 1.0000e-04
# Epoch 24/25
# 44/44 [==============================] - 12s 279ms/step - loss: 1.1350 - accuracy: 0.5879 - val_loss: 8.0524 - val_accuracy: 0.1338 - lr: 1.0000e-04
# Epoch 25/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1357 - accuracy: 0.5886 - val_loss: 1.8409 - val_accuracy: 0.1549 - lr: 1.0000e-04

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.1532934131736527
# Precision of the Model is 0.407369460282622
# Recall of the Model is 0.1532934131736527
# F1 Score of the Model is 0.07992913691800926

# %% [markdown]
# # Experiment 4: VGG Model

# %%
# Define the VGGNet-based model
def create_vggnet_model(input_shape, num_classes):
    model = Sequential()

    # Block 1
    model.add(Conv1D(64, kernel_size=1, activation='relu', padding='same', input_shape=input_shape))
    model.add(Conv1D(64, kernel_size=1, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=1, strides=1))

    # Block 2
    model.add(Conv1D(128, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(128, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=1))

    # Block 3
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Block 4
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Block 5
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Fully connected layers
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
vggnet_model = create_vggnet_model(input_shape, 5)

# %%
history = compile_and_fit(vggnet_model,"expt4_vggnet_model",optimizer='adam',epochs=15,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (None, 12, 64)            64064
#
#  conv1d_12 (Conv1D)          (None, 12, 64)            4160
#
#  max_pooling1d_5 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 12, 128)           16512
#
#  conv1d_14 (Conv1D)          (None, 12, 128)           32896
#
#  max_pooling1d_6 (MaxPooling  (None, 11, 128)          0
#  1D)
#
#  conv1d_15 (Conv1D)          (None, 11, 256)           65792
#
#  conv1d_16 (Conv1D)          (None, 11, 256)           131328
#
#  conv1d_17 (Conv1D)          (None, 11, 256)           131328
#
#  max_pooling1d_7 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  conv1d_18 (Conv1D)          (None, 5, 512)            262656
#
#  conv1d_19 (Conv1D)          (None, 5, 512)            524800
#
#  conv1d_20 (Conv1D)          (None, 5, 512)            524800
#
#  max_pooling1d_8 (MaxPooling  (None, 2, 512)           0
#  1D)
#
#  conv1d_21 (Conv1D)          (None, 2, 512)            524800
#
#  conv1d_22 (Conv1D)          (None, 2, 512)            524800
#
#  conv1d_23 (Conv1D)          (None, 2, 512)            524800
#
#  max_pooling1d_9 (MaxPooling  (None, 1, 512)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 4096)              2101248
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  dense_8 (Dense)             (None, 5)                 20485
#
# =================================================================
# Total params: 22,235,781
# Trainable params: 22,235,781
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 44/44 [==============================] - 78s 2s/step - loss: 1.4144 - accuracy: 0.5553 - val_loss: 1.2826 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/15
# 44/44 [==============================] - 75s 2s/step - loss: 1.2659 - accuracy: 0.5553 - val_loss: 1.2843 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/15
# 44/44 [==============================] - 75s 2s/step - loss: 1.2669 - accuracy: 0.5553 - val_loss: 1.2835 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2659 - accuracy: 0.5553 - val_loss: 1.2830 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2659 - accuracy: 0.5553 - val_loss: 1.2708 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 6/15
# 44/44 [==============================] - 75s 2s/step - loss: 1.2611 - accuracy: 0.5553 - val_loss: 1.2704 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 7/15
# 44/44 [==============================] - 73s 2s/step - loss: 1.2609 - accuracy: 0.5553 - val_loss: 1.2705 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 8/15
# 44/44 [==============================] - 73s 2s/step - loss: 1.2610 - accuracy: 0.5553 - val_loss: 1.2705 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 9/15
# 44/44 [==============================] - 73s 2s/step - loss: 1.2610 - accuracy: 0.5553 - val_loss: 1.2706 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 10/15
# 44/44 [==============================] - 73s 2s/step - loss: 1.2610 - accuracy: 0.5553 - val_loss: 1.2689 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 11/15
# 44/44 [==============================] - 72s 2s/step - loss: 1.2596 - accuracy: 0.5553 - val_loss: 1.2689 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 12/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2597 - accuracy: 0.5553 - val_loss: 1.2689 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 13/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2597 - accuracy: 0.5553 - val_loss: 1.2689 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 14/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2598 - accuracy: 0.5553 - val_loss: 1.2689 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 15/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2598 - accuracy: 0.5553 - val_loss: 1.2690 - val_accuracy: 0.5544 - lr: 1.0000e-04

# %%
display_output(vggnet_model, history)
# Out:
# 53/53 [==============================] - 2s 32ms/step
# 53/53 [==============================] - 2s 32ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5401197604790419
# Precision of the Model is 0.2917293556599376
# Recall of the Model is 0.5401197604790419
# F1 Score of the Model is 0.3788398320000745

# %% [markdown]
# # Experiment 5 - # 1-D CNN, Multi-head attention (Feature Selection) 188 features

# %%
X_train, Y_train = load_data('/kaggle/input/ecg-features-train/X_Features_train.npz', 'train', "X", "Y")
X_val, Y_val = load_data('/kaggle/input/ecg-features-fe/X_Features_val.npz','val', "X", "Y")
X_test, Y_test = load_data('/kaggle/input/ecg-features-fe/X_Features_test.npz','test', "X","Y")
# Out:
# Shape of X-train and Y_train : (11297, 12, 188),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 188),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 188),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 188)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 188)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape)

# %%
history = compile_and_fit(conv1d_mha_model,"expt5_cnn_mha_model",optimizer='adam',epochs=100,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 12, 188)]    0           []
#
#  conv1d_24 (Conv1D)             (None, 12, 32)       6048        ['input_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 32)      128         ['conv1d_24[0][0]']
#  ormalization)
#
#  conv1d_25 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 64)      256         ['conv1d_25[0][0]']
#  ormalization)
#
#  max_pooling1d_10 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_14[0][0]']
#  )
#
#  dropout_9 (Dropout)            (None, 12, 64)       0           ['max_pooling1d_10[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 12, 128)      8320        ['dropout_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 12, 128)     512         ['conv1d_26[0][0]']
#  ormalization)
#
#  dropout_10 (Dropout)           (None, 12, 128)      0           ['batch_normalization_15[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 12, 128)      16512       ['dropout_10[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 12, 128)     512         ['conv1d_27[0][0]']
#  ormalization)
#
#  max_pooling1d_11 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_16[0][0]']
#  )
#
#  conv1d_28 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 12, 512)     2048        ['conv1d_28[0][0]']
#  ormalization)
#
#  conv1d_29 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_17[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 12, 512)     31277       ['conv1d_29[0][0]',
#  eadAttention)                                                    'conv1d_29[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_1[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 12, 1024)     0           ['conv1d_29[0][0]',
#                                                                   'layer_normalization_1[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 1024)        0           ['concatenate_1[0][0]']
#  obalAveragePooling1D)
#
#  dropout_11 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 256)          262400      ['dropout_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 256)          0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 128)          32896       ['dropout_12[0][0]']
#
#  dense_11 (Dense)               (None, 5)            645         ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 693,394
# Trainable params: 691,666
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 19s 308ms/step - loss: 1.4482 - accuracy: 0.5272 - val_loss: 1.4858 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 11s 257ms/step - loss: 1.3601 - accuracy: 0.5547 - val_loss: 1.4468 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] -
- lr: 1.0000e-04
# Epoch 76/100
# 44/44 [==============================] - 11s 258ms/step - loss: 1.0359 - accuracy: 0.6507 - val_loss: 1.1901 - val_accuracy: 0.5967 - lr: 1.0000e-04
# Epoch 77/100
# 44/44 [==============================] - 11s 258ms/step - loss: 1.0340 - accuracy: 0.6522 - val_loss: 1.1894 - val_accuracy: 0.5957 - lr: 1.0000e-04
# Epoch 78/100
# 44/44 [==============================] - 11s 255ms/step - loss: 1.0410 - accuracy: 0.6503 - val_loss: 1.1877 - val_accuracy: 0.5954 - lr: 1.0000e-04
# Epoch 79/100
# 44/44 [==============================] - 11s 257ms/step - loss: 1.0350 - accuracy: 0.6516 - val_loss: 1.1927 - val_accuracy: 0.5954 - lr: 1.0000e-04
# Epoch 80/100
# 44/44 [==============================] - 12s 262ms/step - loss: 1.0314 - accuracy: 0.6541 - val_loss: 1.1927 - val_accuracy: 0.5957 - lr: 1.0000e-04
# Epoch 81/100
# 44/44 [==============================] - 11s 257ms/step - loss: 1.0326 - accuracy: 0.6536 - val_loss: 1.1952 - val_accuracy: 0.5954 - lr: 1.0000e-04
# Epoch 82/100
# 44/44 [==============================] - 12s 262ms/step - loss: 1.0314 - accuracy: 0.6513 - val_loss: 1.1914 - val_accuracy: 0.5977 - lr: 1.0000e-04
# Epoch 83/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.0344 - accuracy: 0.6509 - val_loss: 1.1950 - val_accuracy: 0.5944 - lr: 1.0000e-04
# Epoch 84/100
# 44/44 [==============================] - 11s 252ms/step - loss: 1.0297 - accuracy: 0.6534 - val_loss: 1.1926 - val_accuracy: 0.5964 - lr: 1.0000e-04
# Epoch 85/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.0347 - accuracy: 0.6517 - val_loss: 1.1970 - val_accuracy: 0.5980 - lr: 1.0000e-04
# Epoch 86/100
# 44/44 [==============================] - 12s 267ms/step - loss: 1.0322 - accuracy: 0.6527 - val_loss: 1.2004 - val_accuracy: 0.5931 - lr: 1.0000e-04
# Epoch 87/100
# 44/44 [==============================] - 11s 261ms/step - loss: 1.0277 - accuracy: 0.6534 - val_loss: 1.2015 - val_accuracy: 0.5931 - lr: 1.0000e-04
# Epoch 88/100
# 44/44 [==============================] - 12s 262ms/step - loss: 1.0317 - accuracy: 0.6538 - val_loss: 1.2092 - val_accuracy: 0.5915 - lr: 1.0000e-04
# Epoch 88: early stopping

# %%
display_output(conv1d_mha_model,history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5796407185628742
# Precision of the Model is 0.5225434081243235
# Recall of the Model is 0.5796407185628742
# F1 Score of the Model is 0.4935932685654188

# %% [markdown]
# # Experiment 5.1 - # 1-D CNN, Multi-head attention (Feature Selection + Additional Features)

# %%
X_train, Y_train = load_data('/kaggle/input/fe-all/X_AllFeatures_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/fe-all/X_AllFeatures_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/fe-all/X_AllFeatures_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 365),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 365),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 365),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
history = compile_and_fit(conv1d_mha_model,"expt5.1_cnn_mha_model",optimizer='adam',epochs=100,batch_size=128,learning_rate=0.001)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 12, 365)]    0           []
#
#  conv1d_30 (Conv1D)             (None, 12, 32)       11712       ['input_3[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 12, 32)      128         ['conv1d_30[0][0]']
#  ormalization)
#
#  conv1d_31 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 12, 64)      256         ['conv1d_31[0][0]']
#  ormalization)
#
#  max_pooling1d_12 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_19[0][0]']
#  )
#
#  dropout_13 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_12[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 12, 128)      8320        ['dropout_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 12, 128)     512         ['conv1d_32[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 12, 128)      0           ['batch_normalization_20[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 12, 128)      16512       ['dropout_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 12, 128)     512         ['conv1d_33[0][0]']
#  ormalization)
#
#  max_pooling1d_13 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_21[0][0]']
#  )
#
#  conv1d_34 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 12, 512)     2048        ['conv1d_34[0][0]']
#  ormalization)
#
#  conv1d_35 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_22[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 12, 512)     31277       ['conv1d_35[0][0]',
#  eadAttention)                                                    'conv1d_35[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_2[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 12, 1024)     0           ['conv1d_35[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 1024)        0           ['concatenate_2[0][0]']
#  obalAveragePooling1D)
#
#  dropout_15 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_3[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 256)          262400      ['dropout_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 256)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None,
100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9293 - accuracy: 0.6603 - val_loss: 1.1472 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 83/100
# 44/44 [==============================] - 12s 264ms/step - loss: 0.9360 - accuracy: 0.6569 - val_loss: 1.1612 - val_accuracy: 0.5947 - lr: 1.0000e-04
# Epoch 84/100
# 44/44 [==============================] - 12s 271ms/step - loss: 0.9273 - accuracy: 0.6615 - val_loss: 1.1674 - val_accuracy: 0.5944 - lr: 1.0000e-04
# Epoch 85/100
# 44/44 [==============================] - 11s 261ms/step - loss: 0.9266 - accuracy: 0.6617 - val_loss: 1.1544 - val_accuracy: 0.5924 - lr: 1.0000e-04
# Epoch 86/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.9237 - accuracy: 0.6626 - val_loss: 1.1652 - val_accuracy: 0.5918 - lr: 1.0000e-04
# Epoch 87/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.9162 - accuracy: 0.6651 - val_loss: 1.1656 - val_accuracy: 0.5928 - lr: 1.0000e-04
# Epoch 88/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9194 - accuracy: 0.6644 - val_loss: 1.1561 - val_accuracy: 0.5941 - lr: 1.0000e-04
# Epoch 89/100
# 44/44 [==============================] - 12s 265ms/step - loss: 0.9118 - accuracy: 0.6662 - val_loss: 1.1774 - val_accuracy: 0.5921 - lr: 1.0000e-04
# Epoch 90/100
# 44/44 [==============================] - 12s 262ms/step - loss: 0.9094 - accuracy: 0.6720 - val_loss: 1.1660 - val_accuracy: 0.5951 - lr: 1.0000e-04
# Epoch 91/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.9094 - accuracy: 0.6682 - val_loss: 1.1572 - val_accuracy: 0.5915 - lr: 1.0000e-04
# Epoch 92/100
# 44/44 [==============================] - 11s 258ms/step - loss: 0.9048 - accuracy: 0.6703 - val_loss: 1.1829 - val_accuracy: 0.5941 - lr: 1.0000e-04
# Epoch 93/100
# 44/44 [==============================] - 12s 275ms/step - loss: 0.9037 - accuracy: 0.6690 - val_loss: 1.1642 - val_accuracy: 0.5951 - lr: 1.0000e-04
# Epoch 94/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.8987 - accuracy: 0.6667 - val_loss: 1.1653 - val_accuracy: 0.5931 - lr: 1.0000e-04
# Epoch 95/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9004 - accuracy: 0.6711 - val_loss: 1.1641 - val_accuracy: 0.5964 - lr: 1.0000e-04
# Epoch 96/100
# 44/44 [==============================] - 12s 271ms/step - loss: 0.8899 - accuracy: 0.6745 - val_loss: 1.1744 - val_accuracy: 0.5960 - lr: 1.0000e-04
# Epoch 97/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.8963 - accuracy: 0.6714 - val_loss: 1.1748 - val_accuracy: 0.5970 - lr: 1.0000e-04
# Epoch 98/100
# 44/44 [==============================] - 12s 269ms/step - loss: 0.8853 - accuracy: 0.6748 - val_loss: 1.1759 - val_accuracy: 0.5947 - lr: 1.0000e-04
# Epoch 98: early stopping

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5826347305389221
# Precision of the Model is 0.530648351081868
# Recall of the Model is 0.5826347305389221
# F1 Score of the Model is 0.5303396869414929

# %% [markdown]
# # Experiment 6 - # 1-D CNN, Multi-head attention + Ensemble Classifier (Raw Signal + Feature Selection)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier

# %%
def create_conv1d_mha_model_Feature_Extractor(input_shape, regularizer=0.01):
    inputs = Input(shape=input_shape)
    
    # Convolutional layers
    conv1 = Conv1D(32, 1, activation='relu')(inputs)
    batch_norm1 =  BatchNormalization()(conv1)
    conv2 = Conv1D(64, 1, activation='relu')(batch_norm1)
    batch_norm2 =  BatchNormalization()(conv2)
    max_pooling1 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm2)
    dropout1 = Dropout(0.2)(max_pooling1)
    conv3 = Conv1D(128, 1, activation='relu')(dropout1)
    batch_norm3 =  BatchNormalization()(conv3)
    dropout2 = Dropout(0.3)(batch_norm3)
    conv4 = Conv1D(128, 1, activation='relu')(dropout2)
    batch_norm4 =  BatchNormalization()(conv4)
    max_pooling2 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm4)
    conv5 = Conv1D(512, 1, activation='relu')(max_pooling2)
    batch_norm5 =  BatchNormalization()(conv5)
    conv6 = Conv1D(512, 1, activation='relu')(batch_norm5)
    # Multi-head attention
    attention = MultiHeadAttention(num_heads=5, key_dim=3)(conv6, conv6)
    attention = LayerNormalization(epsilon=1e-6)(attention)
    
    # Concatenate attention output and conv3
    concat = Concatenate()([conv6, attention])
    
    # Global average pooling
    pool = tf.keras.layers.GlobalAveragePooling1D()(concat)
    
    dropout3 = Dropout(0.3)(pool)
    
     # Dense layers
    dense = Dense(996, activation='relu')(dropout3)
    
    model = Model(inputs=inputs, outputs=dense)
    
    return model

# %%
X_raw_train, Y_raw_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_raw_val, Y_raw_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_raw_test, Y_raw_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_raw_train, Y_raw_train)
val_ds = create_dataset(X_raw_val, Y_raw_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_raw_train.shape[1:]
conv1d_mha_model_fe = create_conv1d_mha_model_Feature_Extractor(input_shape)

# %%
X_train_features_DL = conv1d_mha_model_fe.predict(X_raw_train)
print(f"Shape of Features extracted from DL {X_train_features_DL.shape}")
# Out:
# 354/354 [==============================] - 4s 12ms/step
# Shape of Features extracted from DL (11297, 996)

# %%
X_val_features_DL = conv1d_mha_model_fe.predict(X_raw_val)
print(f"Shape of Features extracted from DL {X_val_features_DL.shape}")
# Out:
# 103/103 [==============================] - 1s 12ms/step
# Shape of Features extracted from DL (3268, 996)

# %%
X_train_features_DL = X_train_features_DL.reshape(X_train_features_DL.shape[0], 12, int(X_train_features_DL.shape[1]/12))
X_val_features_DL = X_val_features_DL.reshape(X_val_features_DL.shape[0], 12, int(X_val_features_DL.shape[1]/12))


X_train_combined = np.concatenate((X_train_features_DL, X_train), axis=2)

# %%
X_val_combined = np.concatenate((X_val_features_DL, X_val), axis=2)

# %%
print(f"Shape of Features combined from DL & FE {X_train_combined.shape}")
print(f"Shape of Features combined from DL & FE {X_val_combined.shape}")
# Out:
# Shape of Features combined from DL & FE (11297, 12, 448)
# Shape of Features combined from DL & FE (3268, 12, 448)

# %%
#Lets do ML ensemble classifier to pass through combined features
models = []
models.append(('decision_tree', DecisionTreeClassifier()))
models.append(('svm', SVC()))
models.append(('knn', KNeighborsClassifier()))

# %%
#X_train_combined = X_train_combined.reshape(X_train_combined.shape[0], X_train_combined.shape[1]*X_train_combined.shape[2])

# %%
# Create the ensemble classifier
#ensemble_classifier = VotingClassifier(models,voting="hard")
# Train the ensemble classifier using the extracted features
#ensemble_classifier.fit(X_train_combined, Y_train) #Y_train

# %%
#X_val_combined = X_val_combined.reshape(X_val_combined.shape[0], X_val_combined.shape[1]*X_val_combined.shape[2])

#y_pred = ensemble_classifier.predict(X_val_combined)

# %% [markdown]
# # Experiment 7 - Raw Signal -> DL Model for Feature Selection and DL Classifier

# %%
def create_cnn_lstm_attention(input_shape):
    # Input layer
    input_layer = Input(shape=input_shape)

    # Convolutional layer for local feature extraction
    conv1 = Conv1D(filters=256, kernel_size=3, activation='relu')(input_layer)
    conv2 = Conv1D(filters=256, kernel_size=5, activation='relu')(conv1)
    conv3 = Conv1D(filters=256, kernel_size=3, activation='relu')(conv2)
    pool1 = MaxPooling1D(pool_size=2)(conv3)

    # LSTM layer for capturing temporal features
    lstm1 = LSTM(units=256, return_sequences=True)(pool1)
    lstm2 = LSTM(units=256, return_sequences=True)(lstm1)
    lstm3 = LSTM(units=512, return_sequences=True)(lstm2)
    lstm4 = LSTM(units=512, return_sequences=True)(lstm3)
    # Attention mechanism to focus on relevant temporal features
    attention = Attention()([lstm3, lstm3])
    pool2 = MaxPooling1D(pool_size=2)(attention)
    # Flatten the output from LSTM and attention layers
    flatten = Flatten()(pool2)

    # Fully connected layer for classification or further processing
    dense_layer = Dense(996, activation='relu')(flatten)
    # Create the model
    model = Model(inputs=input_layer, outputs=dense_layer)
    return model

# %%
input_shape = X_train.shape[1:]
cnn_lstm_model = create_cnn_lstm_attention(input_shape)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']

# %%
#history = compile_and_fit(cnn_lstm_model,"expt7_cnn_lstm_model",optimizer='adam',epochs=50,batch_size=256,learning_rate=0.001)

# %%
X_train_features_DL = cnn_lstm_model.predict(X_train)
print(f"Shape of Features extracted from DL {X_train_features_DL.shape}")
# Out:
# 354/354 [==============================] - 9s 22ms/step
# Shape of Features extracted from DL (11297, 996)

# %%
X_val_features_DL = cnn_lstm_model.predict(X_val)
print(f"Shape of Features extracted from DL {X_val_features_DL.shape}")
# Out:
# 103/103 [==============================] - 2s 18ms/step
# Shape of Features extracted from DL (3268, 996)

# %%
X_train_features_DL = X_train_features_DL.reshape(X_train_features_DL.shape[0], 12, int(X_train_features_DL.shape[1]/12))
X_val_features_DL = X_val_features_DL.reshape(X_val_features_DL.shape[0], 12, int(X_val_features_DL.shape[1]/12))

print(f"Shape of Features Reshaped from DL {X_train_features_DL.shape}")
print(f"Shape of Features Reshaped from DL {X_val_features_DL.shape}")
# Out:
# Shape of Features Reshaped from DL (11297, 12, 83)
# Shape of Features Reshaped from DL (3268, 12, 83)

# %%
X_test = cnn_lstm_model.predict(X_test)
print(f"Shape of Features extracted from DL {X_test.shape}")
# Out:
# 53/53 [==============================] - 1s 18ms/step
# Shape of Features extracted from DL (1670, 996)

# %%
X_test = X_test.reshape(X_test.shape[0], 12, int(X_test.shape[1]/12))

# %%
train_ds = create_dataset(X_train_features_DL, Y_train)
val_ds = create_dataset(X_val_features_DL, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 83)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 83)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train_features_DL.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
history = compile_and_fit(conv1d_mha_model,"expt6_FS_cnn_mha_model",optimizer='adam',epochs=15,batch_size=128,learning_rate=0.001)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 12, 83)]     0           []
#
#  conv1d_45 (Conv1D)             (None, 12, 32)       2688        ['input_6[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 12, 32)      128         ['conv1d_45[0][0]']
#  ormalization)
#
#  conv1d_46 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 12, 64)      256         ['conv1d_46[0][0]']
#  ormalization)
#
#  max_pooling1d_18 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_29[0][0]']
#  )
#
#  dropout_20 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_18[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 12, 128)      8320        ['dropout_20[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 12, 128)     512         ['conv1d_47[0][0]']
#  ormalization)
#
#  dropout_21 (Dropout)           (None, 12, 128)      0           ['batch_normalization_30[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 12, 128)      16512       ['dropout_21[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 12, 128)     512         ['conv1d_48[0][0]']
#  ormalization)
#
#  max_pooling1d_19 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_31[0][0]']
#  )
#
#  conv1d_49 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_19[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 12, 512)     2048        ['conv1d_49[0][0]']
#  ormalization)
#
#  conv1d_50 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_32[0][0]']
#
#  multi_head_attention_4 (MultiH  (None, 12, 512)     31277       ['conv1d_50[0][0]',
#  eadAttention)                                                    'conv1d_50[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_4[0][0]']
#  rmalization)
#
#  concatenate_4 (Concatenate)    (None, 12, 1024)     0           ['conv1d_50[0][0]',
#                                                                   'layer_normalization_4[0][0]']
#
#  global_average_pooling1d_5 (Gl  (None, 1024)        0           ['concatenate_4[0][0]']
#  obalAveragePooling1D)
#
#  dropout_22 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_5[0][0
#                                                                  ]']
#
#  dense_17 (Dense)               (None, 256)          262400      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 256)          0           ['dense_17[0][0]']
#
#  dense_18 (Dense)               (None, 128)          32896       ['dropout_23[0][0]']
#
#  dense_19 (Dense)               (None, 5)            645         ['dense_18[0][0]']
#
# ==================================================================================================
# Total params: 690,034
# Trainable params: 688,306
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/15
# 44/44 [==============================] - 17s 275ms/step - loss: 1.3710 - accuracy: 0.5278 - val_loss: 1.4559 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/15
# 44/44 [==============================] - 12s 265ms/step - loss: 1.3050 - accuracy: 0.5546 - val_loss: 1.3469 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/15
# 44/44 [==============================] - 12s 264ms/step - loss: 1.2935 - accuracy: 0.5549 - val_loss: 1.3447 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/15
# 44/44 [==============================] - 12s 268ms/step - loss: 1.2881 - accuracy: 0.5549 - val_loss: 1.3434 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/15
# 44/44 [==============================] - 12s 268ms/step - loss: 1.2743 - accuracy: 0.5580 - val_loss: 1.3047 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/15
# 44/44 [==============================] - 12s 267ms/step - loss: 1.2667 - accuracy: 0.5574 - val_loss: 1.2863 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/15
# 44/44 [==============================] - 11s 260ms/step - loss: 1.2601 - accuracy: 0.5589 - val_loss: 1.3097 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/15
# 44/44 [==============================] - 12s 263ms/step - loss: 1.2555 - accuracy: 0.5580 - val_loss: 1.2924 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/15
# 44/44 [==============================] - 12s 268ms/step - loss: 1.2492 - accuracy: 0.5608 - val_loss: 1.3013 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 10/15
# 44/44 [==============================] - 11s 261ms/step - loss: 1.2388 - accuracy: 0.5613 - val_loss: 1.2766 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 11/15
# 44/44 [==============================] - 12s 268ms/step - loss: 1.2309 - accuracy: 0.5624 - val_loss: 1.2775 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 12/15
# 44/44 [==============================] - 11s 259ms/step - loss: 1.2280 - accuracy: 0.5643 - val_loss: 1.2766 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 13/15
# 44/44 [==============================] - 12s 265ms/step - loss: 1.2278 - accuracy: 0.5634 - val_loss: 1.3134 - val_accuracy: 0.5547 - lr: 2.0000e-04
# Epoch 14/15
# 44/44 [==============================] - 12s 264ms/step - loss: 1.2268 - accuracy: 0.5629 - val_loss: 1.2680 - val_accuracy: 0.5550 - lr: 1.0000e-04
# Epoch 15/15
# 44/44 [==============================] - 12s 263ms/step - loss: 1.2196 - accuracy: 0.5636 - val_loss: 1.2688 - val_accuracy: 0.5579 - lr: 1.0000e-04

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 12ms/step
# 53/53 [==============================] - 1s 9ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5419161676646707
# Precision of the Model is 0.3522387576020538
# Recall of the Model is 0.5419161676646707
# F1 Score of the Model is 0.3833608462469626

# %% [markdown]
# # Experiment 8 - DL Model (FE) + FS

# %%
X_train, Y_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
cnn_lstm_model = create_cnn_lstm_attention(input_shape)

# %%
X_train.shape
# Out:
# (11297, 12, 1000)

# %%
X_train_features_DL = cnn_lstm_model.predict(X_train)
print(f"Shape of Features extracted from DL {X_train_features_DL.shape}")
# Out:
# 354/354 [==============================] - 8s 20ms/step
# Shape of Features extracted from DL (11297, 996)

# %%
X_val_features_DL = cnn_lstm_model.predict(X_val)
print(f"Shape of Features extracted from DL {X_val_features_DL.shape}")
# Out:
# 103/103 [==============================] - 2s 19ms/step
# Shape of Features extracted from DL (3268, 996)

# %%
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
X_val.shape
# Out:
# (3268, 12, 1000)

# %%
X_test_features_DL = cnn_lstm_model.predict(X_test)
print(f"Shape of Features extracted from DL {X_test_features_DL.shape}")
# Out:
# 53/53 [==============================] - 1s 19ms/step
# Shape of Features extracted from DL (1670, 996)

# %%
X_train_features_DL = X_train_features_DL.reshape(X_train_features_DL.shape[0], 12, int(X_train_features_DL.shape[1]/12))
X_val_features_DL = X_val_features_DL.reshape(X_val_features_DL.shape[0], 12, int(X_val_features_DL.shape[1]/12))
X_test_features_DL = X_test_features_DL.reshape(X_test_features_DL.shape[0], 12, int(X_test_features_DL.shape[1]/12))

print(f"Shape of Features Reshaped from DL {X_train_features_DL.shape}")
print(f"Shape of Features Reshaped from DL {X_val_features_DL.shape}")
print(f"Shape of Features Reshaped from DL {X_test_features_DL.shape}")
# Out:
# Shape of Features Reshaped from DL (11297, 12, 83)
# Shape of Features Reshaped from DL (3268, 12, 83)
# Shape of Features Reshaped from DL (1670, 12, 83)

# %%
X_train_Fs, Y_train_Fs = load_data('/kaggle/input/fe-all/X_AllFeatures_train.npz', 'train')
X_val_Fs, Y_val_Fs = load_data('/kaggle/input/fe-all/X_AllFeatures_val.npz','val')
X_test_Fs, Y_test_Fs = load_data('/kaggle/input/fe-all/X_AllFeatures_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 365),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 365),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 365),  (1670,)

# %%
X_train_combined = np.concatenate((X_train_features_DL, X_train_Fs), axis=2)
X_val_combined = np.concatenate((X_val_features_DL, X_val_Fs), axis=2)
X_test_combined = np.concatenate((X_test_features_DL, X_test_Fs), axis=2)


print(f"Shape of Features Reshaped from DL {X_train_combined.shape}")
print(f"Shape of Features Reshaped from DL {X_val_combined.shape}")
print(f"Shape of Features Reshaped from DL {X_test_combined.shape}")
# Out:
# Shape of Features Reshaped from DL (11297, 12, 448)
# Shape of Features Reshaped from DL (3268, 12, 448)
# Shape of Features Reshaped from DL (1670, 12, 448)

# %%
input_shape = X_train_combined.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
train_ds = create_dataset(X_train_combined, Y_train)
val_ds = create_dataset(X_val_combined, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 448)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 448)', 'Shape of Batched Dataset (256,)']

# %%
history = compile_and_fit(conv1d_mha_model,"expt_FS_cnn_mha_combined_model",optimizer='adam',epochs=100,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 12, 448)]    0           []
#
#  conv1d_54 (Conv1D)             (None, 12, 32)       14368       ['input_8[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 12, 32)      128         ['conv1d_54[0][0]']
#  ormalization)
#
#  conv1d_55 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 12, 64)      256         ['conv1d_55[0][0]']
#  ormalization)
#
#  max_pooling1d_22 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_34[0][0]']
#  )
#
#  dropout_24 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_22[0][0]']
#
#  conv1d_56 (Conv1D)             (None, 12, 128)      8320        ['dropout_24[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 12, 128)     512         ['conv1d_56[0][0]']
#  ormalization)
#
#  dropout_25 (Dropout)           (None, 12, 128)      0           ['batch_normalization_35[0][0]']
#
#  conv1d_57 (Conv1D)             (None, 12, 128)      16512       ['dropout_25[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 12, 128)     512         ['conv1d_57[0][0]']
#  ormalization)
#
#  max_pooling1d_23 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_36[0][0]']
#  )
#
#  conv1d_58 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_23[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 12, 512)     2048        ['conv1d_58[0][0]']
#  ormalization)
#
#  conv1d_59 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_37[0][0]']
#
#  multi_head_attention_5 (MultiH  (None, 12, 512)     31277       ['conv1d_59[0][0]',
#  eadAttention)                                                    'conv1d_59[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_5[0][0]']
#  rmalization)
#
#  concatenate_5 (Concatenate)    (None, 12, 1024)     0           ['conv1d_59[0][0]',
#                                                                   'layer_normalization_5[0][0]']
#
#  global_average_pooling1d_6 (Gl  (None, 1024)        0           ['concatenate_5[0][0]']
#  obalAveragePooling1D)
#
#  dropout_26 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_6[0][0
#                                                                  ]']
#
#  dense_21 (Dense)               (None, 256)          262400      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)           (None, 256)          0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 128)          32896       ['dropout_27[0][0]']
#
#  dense_23 (Dense)               (None, 5)            645         ['dense_22[0][0]']
#
# ==================================================================================================
# Total params: 701,714
# Trainable params: 699,986
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 17s 283ms/step - loss: 1.3729 - accuracy: 0.5240 - val_loss: 1.3180 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 12s 268ms/step - loss: 1.2558 - accuracy: 0.5556 - val_loss: 1.3705 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] - 12s 274ms/step - loss: 1.2255 - accuracy: 0.5637 - val_loss: 1.4674 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/100
# 44/44 [==============================] - 12s 269ms/step - loss: 1.2016 - accuracy: 0.5704 - val_loss: 1.4881 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/100
# 44/44 [==============================] - 12s 268ms/step - loss: 1.1775 - accuracy: 0.5764 - val_loss: 1.7124 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 6/100
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1594 - accuracy: 0.5803 - val_loss: 1.7735 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 7/100
# 44/44 [==============================] - 12s 271ms/step - loss: 1.1513 - accuracy: 0.5818 - val_loss: 1.6716 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 8/100
# 44/44 [==============================] - 12s 272ms/step - loss: 1.1400 - accuracy: 0.5860 - val_loss: 1.5955 - val_accuracy: 0.5547 - lr: 1.0000e-04
# Epoch 9/100
# 44/44 [==============================] - 12s 273ms/step - loss: 1.1369 - accuracy: 0.5838 - val_loss: 1.4573 - val_accuracy: 0.5560 - lr: 1.0000e-04
# Epoch 10/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.1343 - accuracy: 0.5850 - val_loss: 1.3787 - val_accuracy: 0.5599 - lr: 1.0000e-04
# Epoch 11/100
# 44/44 [==============================] - 12s 269ms/step - loss: 1.1333 - accuracy: 0.5858 - val_loss: 1.2835 - val_accuracy: 0.5622 - lr: 1.0000e-04
# Epoch 12/100
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1188 - accuracy: 0.5898 - val_loss: 1.2248 - val_accuracy: 0.5654 - lr: 1.0000e-04
# Epoch 13/100
# 44/44 [==============================] - 12s 266ms/step - loss: 1.1203 - accuracy: 0.5866 - val_loss: 1.2026 - val_accuracy: 0.5677 - lr: 1.0000e-04
# Epoch 14/100
# 44/44 [==============================] - 12s 267ms/step - loss: 1.1163 - accuracy: 0.5909 - val_loss: 1.1890 - val_accuracy: 0.5713 - lr: 1.0000e-04
# Epoch 15/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.1153 - accuracy: 0.5867 - val_loss: 1.1844 - val_accuracy: 0.5729 - lr: 1.0000e-04
# Epoch 16/100
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1091 - accuracy: 0.5914 - val_loss: 1.1729 - val_accuracy: 0.5775 - lr: 1.0000e-04
# Epoch 17/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.1052 - accuracy: 0.5914 - val_loss: 1.1692 - val_accuracy: 0.5801 - lr: 1.0000e-04
# Epoch 18/100
# 44/44 [==============================] - 12s 273ms/step - loss: 1.1059 - accuracy: 0.5911 - val_loss: 1.1627 - val_accuracy: 0.5791 - lr: 1.0000e-04
# Epoch 19/100
# 44/44 [==============================] - 12s 261ms/step - loss: 1.0982 - accuracy: 0.5912 - val_loss: 1.1661 - val_accuracy: 0.5794 - lr: 1.0000e-04
# Epoch 20/100
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1011 - accuracy: 0.5922 - val_loss: 1.1596 - val_accuracy: 0.5859 - lr: 1.0000e-04
# Epoch 21/100
# 44/44 [==============================] - 12s 267ms/step - loss: 1.
- val_accuracy: 0.5895 - lr: 1.0000e-04
# Epoch 65/100
# 44/44 [==============================] - 12s 266ms/step - loss: 0.9599 - accuracy: 0.6449 - val_loss: 1.1374 - val_accuracy: 0.5892 - lr: 1.0000e-04
# Epoch 66/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.9573 - accuracy: 0.6517 - val_loss: 1.1580 - val_accuracy: 0.5820 - lr: 1.0000e-04
# Epoch 67/100
# 44/44 [==============================] - 12s 268ms/step - loss: 0.9559 - accuracy: 0.6531 - val_loss: 1.1607 - val_accuracy: 0.5811 - lr: 1.0000e-04
# Epoch 68/100
# 44/44 [==============================] - 12s 265ms/step - loss: 0.9566 - accuracy: 0.6488 - val_loss: 1.1647 - val_accuracy: 0.5879 - lr: 1.0000e-04
# Epoch 69/100
# 44/44 [==============================] - 12s 267ms/step - loss: 0.9489 - accuracy: 0.6495 - val_loss: 1.1733 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 70/100
# 44/44 [==============================] - 12s 265ms/step - loss: 0.9404 - accuracy: 0.6557 - val_loss: 1.1803 - val_accuracy: 0.5820 - lr: 1.0000e-04
# Epoch 71/100
# 44/44 [==============================] - 12s 266ms/step - loss: 0.9433 - accuracy: 0.6520 - val_loss: 1.1570 - val_accuracy: 0.5915 - lr: 1.0000e-04
# Epoch 72/100
# 44/44 [==============================] - 12s 267ms/step - loss: 0.9360 - accuracy: 0.6552 - val_loss: 1.1693 - val_accuracy: 0.5889 - lr: 1.0000e-04
# Epoch 73/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.9409 - accuracy: 0.6535 - val_loss: 1.1699 - val_accuracy: 0.5885 - lr: 1.0000e-04
# Epoch 74/100
# 44/44 [==============================] - 12s 264ms/step - loss: 0.9348 - accuracy: 0.6562 - val_loss: 1.1638 - val_accuracy: 0.5908 - lr: 1.0000e-04
# Epoch 75/100
# 44/44 [==============================] - 13s 286ms/step - loss: 0.9375 - accuracy: 0.6584 - val_loss: 1.1555 - val_accuracy: 0.5866 - lr: 1.0000e-04
# Epoch 76/100
# 44/44 [==============================] - 12s 271ms/step - loss: 0.9292 - accuracy: 0.6586 - val_loss: 1.1531 - val_accuracy: 0.5960 - lr: 1.0000e-04
# Epoch 77/100
# 44/44 [==============================] - 12s 280ms/step - loss: 0.9229 - accuracy: 0.6581 - val_loss: 1.1519 - val_accuracy: 0.5928 - lr: 1.0000e-04
# Epoch 78/100
# 44/44 [==============================] - 12s 279ms/step - loss: 0.9326 - accuracy: 0.6545 - val_loss: 1.1825 - val_accuracy: 0.5882 - lr: 1.0000e-04
# Epoch 79/100
# 44/44 [==============================] - 12s 277ms/step - loss: 0.9268 - accuracy: 0.6584 - val_loss: 1.1599 - val_accuracy: 0.5934 - lr: 1.0000e-04
# Epoch 80/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9202 - accuracy: 0.6650 - val_loss: 1.1477 - val_accuracy: 0.5921 - lr: 1.0000e-04
# Epoch 81/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.9167 - accuracy: 0.6619 - val_loss: 1.1427 - val_accuracy: 0.5951 - lr: 1.0000e-04
# Epoch 82/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.9124 - accuracy: 0.6646 - val_loss: 1.1704 - val_accuracy: 0.5879 - lr: 1.0000e-04
# Epoch 83/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.9107 - accuracy: 0.6634 - val_loss: 1.1574 - val_accuracy: 0.5915 - lr: 1.0000e-04
# Epoch 84/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.9121 - accuracy: 0.6651 - val_loss: 1.1592 - val_accuracy: 0.5928 - lr: 1.0000e-04
# Epoch 85/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.9054 - accuracy: 0.6671 - val_loss: 1.1658 - val_accuracy: 0.5908 - lr: 1.0000e-04
# Epoch 86/100
# 44/44 [==============================] - 12s 274ms/step - loss: 0.8985 - accuracy: 0.6690 - val_loss: 1.1683 - val_accuracy: 0.5892 - lr: 1.0000e-04
# Epoch 87/100
# 44/44 [==============================] - 12s 275ms/step - loss: 0.9031 - accuracy: 0.6705 - val_loss: 1.1464 - val_accuracy: 0.5892 - lr: 1.0000e-04
# Epoch 88/100
# 44/44 [==============================] - 12s 265ms/step - loss: 0.9046 - accuracy: 0.6732 - val_loss: 1.1723 - val_accuracy: 0.5889 - lr: 1.0000e-04
# Epoch 89/100
# 44/44 [==============================] - 12s 276ms/step - loss: 0.9029 - accuracy: 0.6710 - val_loss: 1.1867 - val_accuracy: 0.5876 - lr: 1.0000e-04
# Epoch 90/100
# 44/44 [==============================] - 12s 269ms/step - loss: 0.8895 - accuracy: 0.6744 - val_loss: 1.1626 - val_accuracy: 0.5876 - lr: 1.0000e-04
# Epoch 91/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.8921 - accuracy: 0.6737 - val_loss: 1.1645 - val_accuracy: 0.5872 - lr: 1.0000e-04
# Epoch 92/100
# 44/44 [==============================] - 11s 259ms/step - loss: 0.8808 - accuracy: 0.6826 - val_loss: 1.1687 - val_accuracy: 0.5837 - lr: 1.0000e-04
# Epoch 93/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.8899 - accuracy: 0.6742 - val_loss: 1.1761 - val_accuracy: 0.5853 - lr: 1.0000e-04
# Epoch 93: early stopping

# %%
#display_output(, history, X_test_combined)

Y_pred = conv1d_mha_model.predict(X_test_combined)
# Out:
# 53/53 [==============================] - 1s 10ms/step

# %%
# Evaluate the model
evaluation = evaluate_model(conv1d_mha_model, Y_test, x_test= X_test_combined)

#plot the history loss
plot_loss(history)

# Access individual evaluation metrics
confusion = evaluation['confusion_matrix']
report = evaluation['classification_report']
print(f"Accuracy of the Model is  {evaluation['accuracy']}")
print (f"Precision of the Model is {evaluation['precision']}")
print (f"Recall of the Model is {evaluation['recall']}")
print(f"F1 Score of the Model is {evaluation['f1_score']}")
#auc = evaluation['auc']
#num_parameters = evaluation['num_parameters']

#plot the confusion matrix and classification report
plot_confusion_matrix(confusion)
plot_classification_report(report)

plot_roc_curves(Y_test, Y_pred)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5664670658682635
# Precision of the Model is 0.5010148130391971
# Recall of the Model is 0.5664670658682635
# F1 Score of the Model is 0.4880482437913651
