# %%
import pandas as pd
import numpy as np
import os
import wfdb
import ast

import tensorflow as tf
from tensorflow import keras
#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # Loading Data

# %%
'''function to load the data from the saved file path for different experiments. 
    Saved Data for future use and for conducting experiments as extracting data is resource intensive'''
def load_data(filepath, type, x_key='x', y_key='y'):
    # Load X_test and Y_test
    data = np.load(filepath)
    x = data[x_key]
    y = data[y_key]

    print (f"Shape of X-{type} and Y_{type} : {x.shape},  {y.shape}")
    return x, y

# %%
'''function to create dataset from the numpy array'''
def create_dataset(x, y, batch_size=256):
    dataset_X = tf.data.Dataset.from_tensor_slices(x)
    dataset_Y = tf.data.Dataset.from_tensor_slices(y)
    dataset =  tf.data.Dataset.zip((dataset_X, dataset_Y))

    ds = dataset.batch(batch_size, drop_remainder=True)

    for batch in ds.take(1):
        print([f"Shape of Batched Dataset {arr.numpy().shape}" for arr in batch])
    
    return ds

# %% [markdown]
# # Utils functions for Building and Evaluating Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, MultiHeadAttention, Dense, Flatten, Input,GlobalAveragePooling1D, BatchNormalization,MaxPooling1D,Attention,LayerNormalization, Dropout,Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_recall_fscore_support, roc_auc_score

def evaluate_model(model, Y_test, x_test=None):
    # Predict labels for the test set
   # Get the predicted probabilities
    if(x_test is None):
        x_test = X_test
        
    Y_pred_prob = model.predict(x_test)

    # Convert the predicted probabilities to class labels
    Y_pred = np.argmax(Y_pred_prob, axis=1)

    # Calculate evaluation metrics
    confusion = confusion_matrix(Y_test, Y_pred)
    report = classification_report(Y_test, Y_pred)
    accuracy = accuracy_score(Y_test, Y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(Y_test, Y_pred, average='weighted')
    #auc = roc_auc_score(Y_test, Y_pred)
    #num_parameters = model.count_params()  # Replace with the appropriate method to count model parameters

    # Create a dictionary of evaluation metrics
    evaluation = {
        'confusion_matrix': confusion,
        'classification_report': report,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        #'auc': auc,
        #'num_parameters': num_parameters
    }

    return evaluation

# %%
import seaborn as sns

def plot_confusion_matrix(confusion):
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion, annot=True, cmap='Blues', fmt='g')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

def plot_classification_report(report):
    # Extract precision, recall, and F1-score from the report
    lines = report.split('\n')[2:-5]
    classes = []
    precision = []
    recall = []
    f1_score = []
    for line in lines:
        row = line.split()
        classes.append(row[0])
        precision.append(float(row[1]))
        recall.append(float(row[2]))
        f1_score.append(float(row[3]))

    # Plot precision, recall, and F1-score
    plt.figure(figsize=(10, 4))
    plt.bar(classes, precision, label='Precision')
    plt.bar(classes, recall, label='Recall')
    plt.bar(classes, f1_score, label='F1-Score')
    plt.xlabel('Classes')
    plt.ylabel('Scores')
    plt.title('Classification Report')
    plt.legend()
    plt.show()
    
def plot_loss(history):
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def plot_roc_curves(Y_test, Y_scores):
    # Compute the number of classes
    num_classes = len(np.unique(Y_test))

    # Compute the fpr, tpr, and roc_auc for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(Y_test == i, Y_scores[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curves for each class
    plt.figure(figsize=(8, 6))

    colors = cycle(['blue', 'red', 'green', 'orange', 'purple'])
    classes = [f'Class {i}' for i in range(num_classes)]

    for i, color in zip(range(num_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of {classes[i]} (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc='lower right')
    plt.show()

# %%
def display_output(model, history, x_test=None):

    if(x_test is None):
        x_test = X_test
    Y_pred = model.predict(x_test)
    # Evaluate the model
    evaluation = evaluate_model(model, Y_test, x_test)
    
    #plot the history loss
    plot_loss(history)
    
    # Access individual evaluation metrics
    confusion = evaluation['confusion_matrix']
    report = evaluation['classification_report']
    print(f"Accuracy of the Model is  {evaluation['accuracy']}")
    print (f"Precision of the Model is {evaluation['precision']}")
    print (f"Recall of the Model is {evaluation['recall']}")
    print(f"F1 Score of the Model is {evaluation['f1_score']}")
    #auc = evaluation['auc']
    #num_parameters = evaluation['num_parameters']

    #plot the confusion matrix and classification report
    plot_confusion_matrix(confusion)
    plot_classification_report(report)

    plot_roc_curves(Y_test, Y_pred)

# %%
def get_optimizer(optimizer, learning_rate):
    if(optimizer=="adam"):
        return tf.keras.optimizers.Adam(learning_rate)
    elif (optimizer=="sgd"):
        return tf.keras.optimizers.SGD(learning_rate)
    elif (optimizer=="rmsprop"):
        return tf.keras.optimizers.RMSprop(learning_rate)
    elif (optimizer=="nadam"):
        return tf.keras.optimizers.Nadam(learning_rate)
    elif (optimizer=="adagrad"):
        return tf.keras.optimizers.Adagrad(learning_rate)
    else:
        return tf.keras.optimizers.Adam(learning_rate)

def get_callbacks(name):
    model_output = f'{name}.h5'
    
    return  [keras.callbacks.ModelCheckpoint(model_output, save_best_only=True, monitor="val_loss"),
                keras.callbacks.ReduceLROnPlateau( monitor="val_loss", factor=0.2, patience=3, min_lr=0.0001),
                keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
    
def compile_and_fit(model, name,optimizer, epochs=30, batch_size=256, learning_rate=0.01,shuffle=False):
    optimizer = get_optimizer(optimizer, learning_rate)

    model.compile(optimizer=optimizer,
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=['accuracy'])
    model.summary()
    history = model.fit(train_ds,
                      epochs=epochs,
                      validation_data=val_ds,
                      callbacks=get_callbacks(name),
                      verbose=1, batch_size=batch_size,shuffle=shuffle)
    return history

# %% [markdown]
# # Experiment 1 : (Raw Signal) --> CNN Model

# %%
X_train, Y_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
#HYPER_PARAMETERS
BATCH_SIZE = 256
num_classes = 5
LEARNING_RATE = 0.01
input_shape = X_train.shape[1:]
activation_fn = 'relu'

# %%
# Create the Conv1D model
def create_conv1d_model(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, activation='relu', input_shape=input_shape, kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Conv1D(256, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv1D(256, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Conv1D(128, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Conv1D(128, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(GlobalAveragePooling1D())
    model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
conv1d_model = create_conv1d_model(input_shape)

# %%
history = compile_and_fit(conv1d_model,"expt1_conv1d_model",optimizer='adam',epochs=20,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 256)           768256
#
#  batch_normalization (BatchN  (None, 10, 256)          1024
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            196864
#
#  batch_normalization_1 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 8, 256)           0
#  )
#
#  dropout (Dropout)           (None, 8, 256)            0
#
#  conv1d_2 (Conv1D)           (None, 6, 256)            196864
#
#  batch_normalization_2 (Batc  (None, 6, 256)           1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 6, 256)            0
#
#  conv1d_3 (Conv1D)           (None, 4, 128)            98432
#
#  batch_normalization_3 (Batc  (None, 4, 128)           512
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 2, 128)            49280
#
#  batch_normalization_4 (Batc  (None, 2, 128)           512
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1024)              132096
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 1,451,013
# Trainable params: 1,448,965
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/20
# 44/44 [==============================] - 14s 236ms/step - loss: 10.8618 - accuracy: 0.5501 - val_loss: 7.3716 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/20
# 44/44 [==============================] - 9s 213ms/step - loss: 5.3876 - accuracy: 0.5718 - val_loss: 4.1805 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/20
# 44/44 [==============================] - 10s 218ms/step - loss: 3.1032 - accuracy: 0.5755 - val_loss: 2.7395 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/20
# 44/44 [==============================] - 10s 223ms/step - loss: 2.1375 - accuracy: 0.5748 - val_loss: 2.1631 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/20
# 44/44 [==============================] - 9s 210ms/step - loss: 1.7464 - accuracy: 0.5767 - val_loss: 3.0618 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 6/20
# 44/44 [==============================] - 9s 211ms/step - loss: 1.5479 - accuracy: 0.5804 - val_loss: 2.7176 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 7/20
# 44/44 [==============================] - 10s 220ms/step - loss: 1.4600 - accuracy: 0.5776 - val_loss: 1.6286 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/20
# 44/44 [==============================] - 10s 215ms/step - loss: 1.4029 - accuracy: 0.5752 - val_loss: 1.4577 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/20
# 44/44 [==============================] - 9s 210ms/step - loss: 1.3680 - accuracy: 0.5769 - val_loss: 11.0945 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 10/20
# 44/44 [==============================] - 9s 209ms/step - loss: 1.3868 - accuracy: 0.5700 - val_loss: 27.5647 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 11/20
# 44/44 [==============================] - 10s 216ms/step - loss: 1.4056 - accuracy: 0.5740 - val_loss: 3.3182 - val_accuracy: 0.1341 - lr: 0.0010
# Epoch 12/20
# 44/44 [==============================] - 9s 209ms/step - loss: 1.3679 - accuracy: 0.5779 - val_loss: 1.4735 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 13/20
# 44/44 [==============================] - 9s 210ms/step - loss: 1.3133 - accuracy: 0.5826 - val_loss: 3.2983 - val_accuracy: 0.1344 - lr: 2.0000e-04
# Epoch 14/20
# 44/44 [==============================] - 10s 220ms/step - loss: 1.2828 - accuracy: 0.5839 - val_loss: 2.9533 - val_accuracy: 0.1344 - lr: 2.0000e-04
# Epoch 15/20
# 44/44 [==============================] - 9s 213ms/step - loss: 1.2612 - accuracy: 0.5875 - val_loss: 8.6107 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 16/20
# 44/44 [==============================] - 9s 210ms/step - loss: 1.2400 - accuracy: 0.5919 - val_loss: 5.5031 - val_accuracy: 0.1341 - lr: 1.0000e-04
# Epoch 17/20
# 44/44 [==============================] - 10s 219ms/step - loss: 1.2273 - accuracy: 0.5927 - val_loss: 1.5137 - val_accuracy: 0.5605 - lr: 1.0000e-04
# Epoch 18/20
# 44/44 [==============================] - 9s 210ms/step - loss: 1.2119 - accuracy: 0.5957 - val_loss: 5.6342 - val_accuracy: 0.1341 - lr: 1.0000e-04
# Epoch 19/20
# 44/44 [==============================] - 9s 210ms/step - loss: 1.1999 - accuracy: 0.5997 - val_loss: 4.8964 - val_accuracy: 0.1341 - lr: 1.0000e-04
# Epoch 20/20
# 44/44 [==============================] - 9s 216ms/step - loss: 1.1883 - accuracy: 0.6007 - val_loss: 12.9799 - val_accuracy: 0.1344 - lr: 1.0000e-04

# %%
display_output(conv1d_model, history)
# Out:
# 53/53 [==============================] - 1s 11ms/step
# 53/53 [==============================] - 1s 11ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.13832335329341316
# Precision of the Model is 0.019133350066334397
# Recall of the Model is 0.13832335329341316
# F1 Score of the Model is 0.03361672236799415

# %% [markdown]
# # Experiment 2: LSTM Model

# %%
# Create the LSTM model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(LSTM(64,return_sequences=True,))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(LSTM(64,return_sequences=True,))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='sigmoid'))
    return model

# %%
lstm_model = create_lstm_model(input_shape)

# %%
history = compile_and_fit(lstm_model,"expt2_lstm_model",optimizer='adam',epochs=25,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 64)            272640
#
#  batch_normalization_5 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 12, 64)            0
#
#  lstm_1 (LSTM)               (None, 12, 64)            33024
#
#  batch_normalization_6 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 12, 64)            0
#
#  lstm_2 (LSTM)               (None, 12, 64)            33024
#
#  batch_normalization_7 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 12, 64)            0
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense_2 (Dense)             (None, 5)                 3845
#
# =================================================================
# Total params: 343,301
# Trainable params: 342,917
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/25
# 44/44 [==============================] - 13s 154ms/step - loss: 1.7458 - accuracy: 0.4263 - val_loss: 1.5808 - val_accuracy: 0.1162 - lr: 0.0010
# Epoch 2/25
# 44/44 [==============================] - 6s 125ms/step - loss: 1.5339 - accuracy: 0.4619 - val_loss: 1.5489 - val_accuracy: 0.1162 - lr: 0.0010
# Epoch 3/25
# 44/44 [==============================] - 6s 133ms/step - loss: 1.4396 - accuracy: 0.4894 - val_loss: 1.5561 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 4/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.4018 - accuracy: 0.5067 - val_loss: 1.5190 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.3794 - accuracy: 0.5163 - val_loss: 1.4782 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.3607 - accuracy: 0.5284 - val_loss: 1.4527 - val_accuracy: 0.5540 - lr: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 5s 121ms/step - loss: 1.3456 - accuracy: 0.5334 - val_loss: 1.3994 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.3396 - accuracy: 0.5414 - val_loss: 1.4726 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 5s 120ms/step - loss: 1.3314 - accuracy: 0.5427 - val_loss: 1.4875 - val_accuracy: 0.5540 - lr: 0.0010
# Epoch 10/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.3293 - accuracy: 0.5475 - val_loss: 1.4637 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 11/25
# 44/44 [==============================] - 5s 121ms/step - loss: 1.3187 - accuracy: 0.5505 - val_loss: 1.4378 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 12/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.3015 - accuracy: 0.5533 - val_loss: 1.3820 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 13/25
# 44/44 [==============================] - 6s 128ms/step - loss: 1.2977 - accuracy: 0.5532 - val_loss: 1.5289 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 14/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.2944 - accuracy: 0.5539 - val_loss: 1.5356 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 15/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.2976 - accuracy: 0.5538 - val_loss: 1.3403 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 16/25
# 44/44 [==============================] - 5s 124ms/step - loss: 1.2954 - accuracy: 0.5534 - val_loss: 1.3169 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 17/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.2994 - accuracy: 0.5539 - val_loss: 1.3233 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 18/25
# 44/44 [==============================] - 6s 126ms/step - loss: 1.2911 - accuracy: 0.5542 - val_loss: 1.3096 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 19/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.2927 - accuracy: 0.5547 - val_loss: 1.3275 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 20/25
# 44/44 [==============================] - 5s 121ms/step - loss: 1.2969 - accuracy: 0.5548 - val_loss: 1.3244 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 21/25
# 44/44 [==============================] - 6s 130ms/step - loss: 1.2947 - accuracy: 0.5547 - val_loss: 1.3218 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 22/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.2866 - accuracy: 0.5550 - val_loss: 1.3198 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 23/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.2884 - accuracy: 0.5551 - val_loss: 1.3376 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 24/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.2888 - accuracy: 0.5550 - val_loss: 1.3390 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 25/25
# 44/44 [==============================] - 6s 130ms/step - loss: 1.2871 - accuracy: 0.5546 - val_loss: 1.3255 - val_accuracy: 0.5544 - lr: 1.0000e-04

# %%
display_output(lstm_model, history)
# Out:
# 53/53 [==============================] - 2s 12ms/step
# 53/53 [==============================] - 1s 13ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5401197604790419
# Precision of the Model is 0.2917293556599376
# Recall of the Model is 0.5401197604790419
# F1 Score of the Model is 0.3788398320000745

# %% [markdown]
# # Experiment 3: 1D CNN MHA (Multi Head Attention) model

# %%
def create_conv1d_mha_model(input_shape, regularizer=0.01):
    inputs = Input(shape=input_shape)
    
    # Convolutional layers
    conv1 = Conv1D(32, 1, activation='relu')(inputs)
    batch_norm1 =  BatchNormalization()(conv1)
    conv2 = Conv1D(64, 1, activation='relu')(batch_norm1)
    batch_norm2 =  BatchNormalization()(conv2)
    max_pooling1 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm2)
    dropout1 = Dropout(0.2)(max_pooling1)
    conv3 = Conv1D(128, 1, activation='relu')(dropout1)
    batch_norm3 =  BatchNormalization()(conv3)
    dropout2 = Dropout(0.3)(batch_norm3)
    conv4 = Conv1D(128, 1, activation='relu')(dropout2)
    batch_norm4 =  BatchNormalization()(conv4)
    max_pooling2 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm4)
    conv5 = Conv1D(512, 1, activation='relu')(max_pooling2)
    batch_norm5 =  BatchNormalization()(conv5)
    conv6 = Conv1D(512, 1, activation='relu')(batch_norm5)
    # Multi-head attention
    attention = MultiHeadAttention(num_heads=5, key_dim=3)(conv6, conv6)
    attention = LayerNormalization(epsilon=1e-6)(attention)
    
    # Concatenate attention output and conv3
    concat = Concatenate()([conv6, attention])
    
    # Global average pooling
    pool = tf.keras.layers.GlobalAveragePooling1D()(concat)
    
    dropout3 = Dropout(0.3)(pool)
    
     # Dense layers
    dense1 = Dense(256, activation='relu')(dropout3)
    dropout4 = Dropout(0.5)(dense1)
    dense2 = Dense(128, activation='relu')(dropout4)
    # Dense layer
    dense = Dense(num_classes, activation='softmax',
                  kernel_regularizer=regularizers.l2(regularizer))(dense2) 
    
    # Create model
    model = Model(inputs=inputs, outputs=dense)
    
    return model

# %%
conv1d_mha_model= create_conv1d_mha_model(input_shape)

# %%
history = compile_and_fit(conv1d_mha_model,"expt3_cnn_mha_model",optimizer='adam',epochs=25,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 12, 1000)]   0           []
#
#  conv1d_5 (Conv1D)              (None, 12, 32)       32032       ['input_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 12, 32)      128         ['conv1d_5[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 12, 64)       2112        ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 12, 64)      256         ['conv1d_6[0][0]']
#  rmalization)
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 12, 64)      0           ['batch_normalization_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 12, 64)       0           ['max_pooling1d_3[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 12, 128)      8320        ['dropout_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 12, 128)     512         ['conv1d_7[0][0]']
#  ormalization)
#
#  dropout_6 (Dropout)            (None, 12, 128)      0           ['batch_normalization_10[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 12, 128)      16512       ['dropout_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 12, 128)     512         ['conv1d_8[0][0]']
#  ormalization)
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 12, 128)     0           ['batch_normalization_11[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 12, 512)      66048       ['max_pooling1d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 12, 512)     2048        ['conv1d_9[0][0]']
#  ormalization)
#
#  conv1d_10 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_12[0][0]']
#
#  multi_head_attention (MultiHea  (None, 12, 512)     31277       ['conv1d_10[0][0]',
#  dAttention)                                                      'conv1d_10[0][0]']
#
#  layer_normalization (LayerNorm  (None, 12, 512)     1024        ['multi_head_attention[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 12, 1024)     0           ['conv1d_10[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 1024)        0           ['concatenate[0][0]']
#  obalAveragePooling1D)
#
#  dropout_7 (Dropout)            (None, 1024)         0           ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 256)          262400      ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['dropout_8[0][0]']
#
#  dense_5 (Dense)                (None, 5)            645         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 719,378
# Trainable params: 717,650
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/25
# 44/44 [==============================] - 17s 291ms/step - loss: 1.4152 - accuracy: 0.5434 - val_loss: 1.4082 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/25
# 44/44 [==============================] - 12s 279ms/step - loss: 1.3148 - accuracy: 0.5723 - val_loss: 1.3902 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/25
# 44/44 [==============================] - 12s 281ms/step - loss: 1.2861 - accuracy: 0.5758 - val_loss: 1.4112 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/25
# 44/44 [==============================] - 12s 280ms/step - loss: 1.2651 - accuracy: 0.5751 - val_loss: 1.3733 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 12s 281ms/step - loss: 1.2509 - accuracy: 0.5760 - val_loss: 1.3723 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 13s 293ms/step - loss: 1.2373 - accuracy: 0.5768 - val_loss: 1.4531 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.2279 - accuracy: 0.5776 - val_loss: 1.4724 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 12s 283ms/step - loss: 1.2171 - accuracy: 0.5782 - val_loss: 1.3621 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 12s 273ms/step - loss: 1.2046 - accuracy: 0.5780 - val_loss: 1.7573 - val_accuracy: 0.1344 - lr: 0.0010
# Epoch 10/25
# 44/44 [==============================] - 12s 282ms/step - loss: 1.1896 - accuracy: 0.5811 - val_loss: 2.4642 - val_accuracy: 0.1341 - lr: 0.0010
# Epoch 11/25
# 44/44 [==============================] - 12s 278ms/step - loss: 1.1795 - accuracy: 0.5801 - val_loss: 5.9889 - val_accuracy: 0.1341 - lr: 0.0010
# Epoch 12/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1589 - accuracy: 0.5822 - val_loss: 3.2030 - val_accuracy: 0.1341 - lr: 2.0000e-04
# Epoch 13/25
# 44/44 [==============================] - 12s 277ms/step - loss: 1.1437 - accuracy: 0.5852 - val_loss: 1.3942 - val_accuracy: 0.5560 - lr: 2.0000e-04
# Epoch 14/25
# 44/44 [==============================] - 12s 279ms/step - loss: 1.1404 - accuracy: 0.5834 - val_loss: 2.7254 - val_accuracy: 0.1341 - lr: 2.0000e-04
# Epoch 15/25
# 44/44 [==============================] - 12s 276ms/step - loss: 1.1335 - accuracy: 0.5850 - val_loss: 1.3914 - val_accuracy: 0.5602 - lr: 1.0000e-04
# Epoch 16/25
# 44/44 [==============================] - 12s 279ms/step - loss: 1.1318 - accuracy: 0.5860 - val_loss: 1.3056 - val_accuracy: 0.5563 - lr: 1.0000e-04
# Epoch 17/25
# 44/44 [==============================] - 12s 279ms/step - loss: 1.1280 - accuracy: 0.5859 - val_loss: 1.2848 - val_accuracy: 0.5560 - lr: 1.0000e-04
# Epoch 18/25
# 44/44 [==============================] - 12s 283ms/step - loss: 1.1247 - accuracy: 0.5869 - val_loss: 1.5284 - val_accuracy: 0.5176 - lr: 1.0000e-04
# Epoch 19/25
# 44/44 [==============================] - 12s 278ms/step - loss: 1.1231 - accuracy: 0.5870 - val_loss: 3.8292 - val_accuracy: 0.1341 - lr: 1.0000e-04
# Epoch 20/25
# 44/44 [==============================] - 12s 281ms/step - loss: 1.1198 - accuracy: 0.5877 - val_loss: 2.2712 - val_accuracy: 0.1344 - lr: 1.0000e-04
# Epoch 21/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1191 - accuracy: 0.5870 - val_loss: 2.7136 - val_accuracy: 0.1341 - lr: 1.0000e-04
# Epoch 22/25
# 44/44 [==============================] - 12s 282ms/step - loss: 1.1180 - accuracy: 0.5885 - val_loss: 1.4780 - val_accuracy: 0.5632 - lr: 1.0000e-04
# Epoch 23/25
# 44/44 [==============================] - 12s 278ms/step - loss: 1.1167 - accuracy: 0.5881 - val_loss: 2.3791 - val_accuracy: 0.1341 - lr: 1.0000e-04
# Epoch 24/25
# 44/44 [==============================] - 13s 286ms/step - loss: 1.1118 - accuracy: 0.5872 - val_loss: 1.2831 - val_accuracy: 0.5592 - lr: 1.0000e-04
# Epoch 25/25
# 44/44 [==============================] - 12s 274ms/step - loss: 1.1059 - accuracy: 0.5890 - val_loss: 1.8498 - val_accuracy: 0.1380 - lr: 1.0000e-04

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.14191616766467066
# Precision of the Model is 0.3090779378742515
# Recall of the Model is 0.14191616766467066
# F1 Score of the Model is 0.05052375766579213

# %% [markdown]
# # Experiment 4: VGG Model

# %%
# Define the VGGNet-based model
def create_vggnet_model(input_shape, num_classes):
    model = Sequential()

    # Block 1
    model.add(Conv1D(64, kernel_size=1, activation='relu', padding='same', input_shape=input_shape))
    model.add(Conv1D(64, kernel_size=1, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=1, strides=1))

    # Block 2
    model.add(Conv1D(128, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(128, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=1))

    # Block 3
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Block 4
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Block 5
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Fully connected layers
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
vggnet_model = create_vggnet_model(input_shape, 5)

# %%
history = compile_and_fit(vggnet_model,"expt4_vggnet_model",optimizer='adam',epochs=15,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (None, 12, 64)            64064
#
#  conv1d_12 (Conv1D)          (None, 12, 64)            4160
#
#  max_pooling1d_5 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 12, 128)           16512
#
#  conv1d_14 (Conv1D)          (None, 12, 128)           32896
#
#  max_pooling1d_6 (MaxPooling  (None, 11, 128)          0
#  1D)
#
#  conv1d_15 (Conv1D)          (None, 11, 256)           65792
#
#  conv1d_16 (Conv1D)          (None, 11, 256)           131328
#
#  conv1d_17 (Conv1D)          (None, 11, 256)           131328
#
#  max_pooling1d_7 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  conv1d_18 (Conv1D)          (None, 5, 512)            262656
#
#  conv1d_19 (Conv1D)          (None, 5, 512)            524800
#
#  conv1d_20 (Conv1D)          (None, 5, 512)            524800
#
#  max_pooling1d_8 (MaxPooling  (None, 2, 512)           0
#  1D)
#
#  conv1d_21 (Conv1D)          (None, 2, 512)            524800
#
#  conv1d_22 (Conv1D)          (None, 2, 512)            524800
#
#  conv1d_23 (Conv1D)          (None, 2, 512)            524800
#
#  max_pooling1d_9 (MaxPooling  (None, 1, 512)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 4096)              2101248
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  dense_8 (Dense)             (None, 5)                 20485
#
# =================================================================
# Total params: 22,235,781
# Trainable params: 22,235,781
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 44/44 [==============================] - 81s 2s/step - loss: 1.3879 - accuracy: 0.5412 - val_loss: 1.2834 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/15
# 44/44 [==============================] - 79s 2s/step - loss: 1.2666 - accuracy: 0.5553 - val_loss: 1.2839 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/15
# 44/44 [==============================] - 77s 2s/step - loss: 1.2668 - accuracy: 0.5553 - val_loss: 1.2843 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/15
# 44/44 [==============================] - 78s 2s/step - loss: 1.2670 - accuracy: 0.5553 - val_loss: 1.2828 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/15
# 44/44 [==============================] - 77s 2s/step - loss: 1.2662 - accuracy: 0.5553 - val_loss: 1.2826 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/15
# 44/44 [==============================] - 77s 2s/step - loss: 1.2654 - accuracy: 0.5553 - val_loss: 1.2819 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/15
# 44/44 [==============================] - 77s 2s/step - loss: 1.2648 - accuracy: 0.5553 - val_loss: 1.2787 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/15
# 44/44 [==============================] - 76s 2s/step - loss: 1.2643 - accuracy: 0.5553 - val_loss: 1.2795 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/15
# 44/44 [==============================] - 77s 2s/step - loss: 1.2646 - accuracy: 0.5553 - val_loss: 1.2774 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 10/15
# 44/44 [==============================] - 77s 2s/step - loss: 1.2649 - accuracy: 0.5553 - val_loss: 1.2746 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 11/15
# 44/44 [==============================] - 79s 2s/step - loss: 1.2643 - accuracy: 0.5553 - val_loss: 1.2724 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 12/15
# 44/44 [==============================] - 79s 2s/step - loss: 1.2631 - accuracy: 0.5553 - val_loss: 1.2718 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 13/15
# 44/44 [==============================] - 80s 2s/step - loss: 1.2627 - accuracy: 0.5553 - val_loss: 1.2715 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 14/15
# 44/44 [==============================] - 79s 2s/step - loss: 1.2625 - accuracy: 0.5553 - val_loss: 1.2711 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 15/15
# 44/44 [==============================] - 78s 2s/step - loss: 1.2623 - accuracy: 0.5553 - val_loss: 1.2710 - val_accuracy: 0.5544 - lr: 0.0010

# %%
display_output(vggnet_model, history)
# Out:
# 53/53 [==============================] - 2s 32ms/step
# 53/53 [==============================] - 2s 32ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5401197604790419
# Precision of the Model is 0.2917293556599376
# Recall of the Model is 0.5401197604790419
# F1 Score of the Model is 0.3788398320000745

# %% [markdown]
# # Experiment 5 - # 1-D CNN, Multi-head attention (Feature Selection) 188 features

# %%
X_train, Y_train = load_data('/kaggle/input/ecg-features-train/X_Features_train.npz', 'train', "X", "Y")
X_val, Y_val = load_data('/kaggle/input/ecg-features-fe/X_Features_val.npz','val', "X", "Y")
X_test, Y_test = load_data('/kaggle/input/ecg-features-fe/X_Features_test.npz','test', "X","Y")
# Out:
# Shape of X-train and Y_train : (11297, 12, 188),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 188),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 188),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 188)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 188)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape)

# %%
history = compile_and_fit(conv1d_mha_model,"expt5_cnn_mha_model",optimizer='adam',epochs=100,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 12, 188)]    0           []
#
#  conv1d_24 (Conv1D)             (None, 12, 32)       6048        ['input_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 32)      128         ['conv1d_24[0][0]']
#  ormalization)
#
#  conv1d_25 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 64)      256         ['conv1d_25[0][0]']
#  ormalization)
#
#  max_pooling1d_10 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_14[0][0]']
#  )
#
#  dropout_9 (Dropout)            (None, 12, 64)       0           ['max_pooling1d_10[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 12, 128)      8320        ['dropout_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 12, 128)     512         ['conv1d_26[0][0]']
#  ormalization)
#
#  dropout_10 (Dropout)           (None, 12, 128)      0           ['batch_normalization_15[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 12, 128)      16512       ['dropout_10[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 12, 128)     512         ['conv1d_27[0][0]']
#  ormalization)
#
#  max_pooling1d_11 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_16[0][0]']
#  )
#
#  conv1d_28 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 12, 512)     2048        ['conv1d_28[0][0]']
#  ormalization)
#
#  conv1d_29 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_17[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 12, 512)     31277       ['conv1d_29[0][0]',
#  eadAttention)                                                    'conv1d_29[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_1[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 12, 1024)     0           ['conv1d_29[0][0]',
#                                                                   'layer_normalization_1[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 1024)        0           ['concatenate_1[0][0]']
#  obalAveragePooling1D)
#
#  dropout_11 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 256)          262400      ['dropout_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 256)          0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 128)          32896       ['dropout_12[0][0]']
#
#  dense_11 (Dense)               (None, 5)            645         ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 693,394
# Trainable params: 691,666
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 19s 325ms/step - loss: 1.4414 - accuracy: 0.5273 - val_loss: 1.4281 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 13s 289ms/step - loss: 1.3271 - accuracy: 0.5657 - val_loss: 1.3920 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] - 12s 271ms/step - loss: 1.3085 - accuracy: 0.5702 - val_loss: 1.3581 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.2842 - accuracy: 0.5744 - val_loss: 1.3410 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/100
# 44/44 [==============================] - 12s 266ms/step - loss: 1.2745 - accuracy: 0.5725 - val_loss: 1.3579 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/100
# 44/44 [==============================] - 12s 266ms/step - loss: 1.2563 - accuracy: 0.5790 - val_loss: 1.3305 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/100
# 44/44 [==============================] - 12s 271ms/step - loss: 1.2485 - accuracy: 0.5772 - val_loss: 1.3454 - val_accuracy: 0.5547 - lr: 0.0010
# Epoch 8/100
# 44/44 [==============================] - 12s 272ms/step - loss: 1.2336 - accuracy: 0.5812 - val_loss: 1.3071 - val_accuracy: 0.5615 - lr: 0.0010
# Epoch 9/100
# 44/44 [==============================] - 12s 266ms/step - loss: 1.2243 - accuracy: 0.5794 - val_loss: 1.3240 - val_accuracy: 0.5641 - lr: 0.0010
# Epoch 10/100
# 44/44 [==============================] - 12s 272ms/step - loss: 1.2163 - accuracy: 0.5845 - val_loss: 1.3054 - val_accuracy: 0.5684 - lr: 0.0010
# Epoch 11/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.2075 - accuracy: 0.5866 - val_loss: 1.2765 - val_accuracy: 0.5755 - lr: 0.0010
# Epoch 12/100
# 44/44 [==============================] - 12s 263ms/step - loss: 1.2051 - accuracy: 0.5866 - val_loss: 1.2882 - val_accuracy: 0.5706 - lr: 0.0010
# Epoch 13/100
# 44/44 [==============================] - 12s 263ms/step - loss: 1.1888 - accuracy: 0.5927 - val_loss: 1.2795 - val_accuracy: 0.5853 - lr: 0.0010
# Epoch 14/100
# 44/44 [==============================] - 12s 275ms/step - loss: 1.1957 - accuracy: 0.5885 - val_loss: 1.2489 - val_accuracy: 0.5824 - lr: 0.0010
# Epoch 15/100
# 44/44 [==============================] - 12s 267ms/step - loss: 1.1831 - accuracy: 0.5985 - val_loss: 1.2784 - val_accuracy: 0.5869 - lr: 0.0010
# Epoch 16/100
# 44/44 [==============================] - 12s 272ms/step - loss: 1.1766 - accuracy: 0.5952 - val_loss: 1.2647 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch 17/100
# 44/44 [==============================] - 12s 269ms/step - loss: 1.1728 - accuracy: 0.5989 - val_loss: 1.2684 - val_accuracy: 0.5833 - lr: 0.0010
# Epoch
100
# 44/44 [==============================] - 12s 264ms/step - loss: 1.0306 - accuracy: 0.6547 - val_loss: 1.2224 - val_accuracy: 0.5824 - lr: 1.0000e-04
# Epoch 95/100
# 44/44 [==============================] - 12s 268ms/step - loss: 1.0322 - accuracy: 0.6510 - val_loss: 1.2174 - val_accuracy: 0.5840 - lr: 1.0000e-04
# Epoch 96/100
# 44/44 [==============================] - 12s 264ms/step - loss: 1.0299 - accuracy: 0.6517 - val_loss: 1.2204 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 97/100
# 44/44 [==============================] - 12s 266ms/step - loss: 1.0231 - accuracy: 0.6565 - val_loss: 1.2269 - val_accuracy: 0.5850 - lr: 1.0000e-04
# Epoch 98/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.0306 - accuracy: 0.6520 - val_loss: 1.2286 - val_accuracy: 0.5817 - lr: 1.0000e-04
# Epoch 99/100
# 44/44 [==============================] - 12s 265ms/step - loss: 1.0246 - accuracy: 0.6558 - val_loss: 1.2282 - val_accuracy: 0.5820 - lr: 1.0000e-04
# Epoch 100/100
# 44/44 [==============================] - 12s 270ms/step - loss: 1.0239 - accuracy: 0.6533 - val_loss: 1.2367 - val_accuracy: 0.5781 - lr: 1.0000e-04

# %%
display_output(conv1d_mha_model,history)
# Out:
# 53/53 [==============================] - 1s 11ms/step
# 53/53 [==============================] - 1s 11ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5754491017964072
# Precision of the Model is 0.5165369996392812
# Recall of the Model is 0.5754491017964072
# F1 Score of the Model is 0.48170057705076036

# %% [markdown]
# # Experiment 5.1 - # 1-D CNN, Multi-head attention (Feature Selection + Additional Features)

# %%
X_train, Y_train = load_data('/kaggle/input/fe-all/X_AllFeatures_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/fe-all/X_AllFeatures_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/fe-all/X_AllFeatures_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 365),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 365),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 365),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
history = compile_and_fit(conv1d_mha_model,"expt5.1_cnn_mha_model",optimizer='adam',epochs=100,batch_size=128,learning_rate=0.001)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 12, 365)]    0           []
#
#  conv1d_30 (Conv1D)             (None, 12, 32)       11712       ['input_3[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 12, 32)      128         ['conv1d_30[0][0]']
#  ormalization)
#
#  conv1d_31 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 12, 64)      256         ['conv1d_31[0][0]']
#  ormalization)
#
#  max_pooling1d_12 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_19[0][0]']
#  )
#
#  dropout_13 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_12[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 12, 128)      8320        ['dropout_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 12, 128)     512         ['conv1d_32[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 12, 128)      0           ['batch_normalization_20[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 12, 128)      16512       ['dropout_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 12, 128)     512         ['conv1d_33[0][0]']
#  ormalization)
#
#  max_pooling1d_13 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_21[0][0]']
#  )
#
#  conv1d_34 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 12, 512)     2048        ['conv1d_34[0][0]']
#  ormalization)
#
#  conv1d_35 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_22[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 12, 512)     31277       ['conv1d_35[0][0]',
#  eadAttention)                                                    'conv1d_35[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_2[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 12, 1024)     0           ['conv1d_35[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 1024)        0           ['concatenate_2[0][0]']
#  obalAveragePooling1D)
#
#  dropout_15 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_3[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 256)          262400      ['dropout_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 256)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 128)          32896       ['dropout_16[0][0]']
#
#  dense_14 (Dense)               (None, 5)            645         ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 699,058
# Trainable params: 697,330
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 17s 280ms/step - loss: 1.3531 - accuracy: 0.5202 - val_loss: 1.4056 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 12s 270ms/step - loss: 1.2562 - accuracy: 0.5531 - val_loss: 1.3331 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] - 12s 271ms/step - loss: 1.2349 - accuracy: 0.5565 - val_loss: 1.2911 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/100
# 44/44 [==============================] - 12s
- lr: 1.0000e-04
# Epoch 66/100
# 44/44 [==============================] - 12s 271ms/step - loss: 0.8761 - accuracy: 0.6815 - val_loss: 1.0921 - val_accuracy: 0.6038 - lr: 1.0000e-04
# Epoch 67/100
# 44/44 [==============================] - 12s 271ms/step - loss: 0.8831 - accuracy: 0.6786 - val_loss: 1.0907 - val_accuracy: 0.6068 - lr: 1.0000e-04
# Epoch 68/100
# 44/44 [==============================] - 12s 268ms/step - loss: 0.8794 - accuracy: 0.6795 - val_loss: 1.0927 - val_accuracy: 0.6025 - lr: 1.0000e-04
# Epoch 69/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.8697 - accuracy: 0.6833 - val_loss: 1.0967 - val_accuracy: 0.6035 - lr: 1.0000e-04
# Epoch 70/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.8738 - accuracy: 0.6792 - val_loss: 1.0946 - val_accuracy: 0.6035 - lr: 1.0000e-04
# Epoch 71/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.8658 - accuracy: 0.6840 - val_loss: 1.0919 - val_accuracy: 0.6012 - lr: 1.0000e-04
# Epoch 72/100
# 44/44 [==============================] - 12s 274ms/step - loss: 0.8742 - accuracy: 0.6808 - val_loss: 1.0971 - val_accuracy: 0.5993 - lr: 1.0000e-04
# Epoch 73/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.8633 - accuracy: 0.6856 - val_loss: 1.1004 - val_accuracy: 0.5999 - lr: 1.0000e-04
# Epoch 74/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.8685 - accuracy: 0.6836 - val_loss: 1.0975 - val_accuracy: 0.6003 - lr: 1.0000e-04
# Epoch 75/100
# 44/44 [==============================] - 12s 277ms/step - loss: 0.8647 - accuracy: 0.6887 - val_loss: 1.0959 - val_accuracy: 0.6009 - lr: 1.0000e-04
# Epoch 76/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.8623 - accuracy: 0.6863 - val_loss: 1.1011 - val_accuracy: 0.6006 - lr: 1.0000e-04
# Epoch 77/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.8567 - accuracy: 0.6870 - val_loss: 1.0998 - val_accuracy: 0.6019 - lr: 1.0000e-04
# Epoch 78/100
# 44/44 [==============================] - 12s 264ms/step - loss: 0.8553 - accuracy: 0.6915 - val_loss: 1.0967 - val_accuracy: 0.6042 - lr: 1.0000e-04
# Epoch 78: early stopping

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5874251497005988
# Precision of the Model is 0.532221445996895
# Recall of the Model is 0.5874251497005988
# F1 Score of the Model is 0.5228306973984179

# %% [markdown]
# # Experiment 6 - # 1-D CNN, Multi-head attention + Ensemble Classifier (Raw Signal + Feature Selection)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import VotingClassifier

# %%
def create_conv1d_mha_model_Feature_Extractor(input_shape, regularizer=0.01):
    inputs = Input(shape=input_shape)
    
    # Convolutional layers
    conv1 = Conv1D(32, 1, activation='relu')(inputs)
    batch_norm1 =  BatchNormalization()(conv1)
    conv2 = Conv1D(64, 1, activation='relu')(batch_norm1)
    batch_norm2 =  BatchNormalization()(conv2)
    max_pooling1 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm2)
    dropout1 = Dropout(0.2)(max_pooling1)
    conv3 = Conv1D(128, 1, activation='relu')(dropout1)
    batch_norm3 =  BatchNormalization()(conv3)
    dropout2 = Dropout(0.3)(batch_norm3)
    conv4 = Conv1D(128, 1, activation='relu')(dropout2)
    batch_norm4 =  BatchNormalization()(conv4)
    max_pooling2 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm4)
    conv5 = Conv1D(512, 1, activation='relu')(max_pooling2)
    batch_norm5 =  BatchNormalization()(conv5)
    conv6 = Conv1D(512, 1, activation='relu')(batch_norm5)
    # Multi-head attention
    attention = MultiHeadAttention(num_heads=5, key_dim=3)(conv6, conv6)
    attention = LayerNormalization(epsilon=1e-6)(attention)
    
    # Concatenate attention output and conv3
    concat = Concatenate()([conv6, attention])
    
    # Global average pooling
    pool = tf.keras.layers.GlobalAveragePooling1D()(concat)
    
    dropout3 = Dropout(0.3)(pool)
    
     # Dense layers
    dense = Dense(996, activation='relu')(dropout3)
    
    model = Model(inputs=inputs, outputs=dense)
    
    return model

# %%
X_raw_train, Y_raw_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_raw_val, Y_raw_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_raw_test, Y_raw_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_raw_train, Y_raw_train)
val_ds = create_dataset(X_raw_val, Y_raw_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_raw_train.shape[1:]
conv1d_mha_model_fe = create_conv1d_mha_model_Feature_Extractor(input_shape)

# %%
X_train_features_DL = conv1d_mha_model_fe.predict(X_raw_train)
print(f"Shape of Features extracted from DL {X_train_features_DL.shape}")
# Out:
# 354/354 [==============================] - 5s 12ms/step
# Shape of Features extracted from DL (11297, 996)

# %%
X_val_features_DL = conv1d_mha_model_fe.predict(X_raw_val)
print(f"Shape of Features extracted from DL {X_val_features_DL.shape}")
# Out:
# 103/103 [==============================] - 1s 11ms/step
# Shape of Features extracted from DL (3268, 996)

# %%
X_train_features_DL = X_train_features_DL.reshape(X_train_features_DL.shape[0], 12, int(X_train_features_DL.shape[1]/12))
X_val_features_DL = X_val_features_DL.reshape(X_val_features_DL.shape[0], 12, int(X_val_features_DL.shape[1]/12))


X_train_combined = np.concatenate((X_train_features_DL, X_train), axis=2)

# %%
X_val_combined = np.concatenate((X_val_features_DL, X_val), axis=2)

# %%
print(f"Shape of Features combined from DL & FE {X_train_combined.shape}")
print(f"Shape of Features combined from DL & FE {X_val_combined.shape}")
# Out:
# Shape of Features combined from DL & FE (11297, 12, 448)
# Shape of Features combined from DL & FE (3268, 12, 448)

# %%
#Lets do ML ensemble classifier to pass through combined features
models = []
models.append(('decision_tree', DecisionTreeClassifier()))
models.append(('svm', SVC()))
models.append(('knn', KNeighborsClassifier()))

# %%
#X_train_combined = X_train_combined.reshape(X_train_combined.shape[0], X_train_combined.shape[1]*X_train_combined.shape[2])

# %%
# Create the ensemble classifier
#ensemble_classifier = VotingClassifier(models,voting="hard")
# Train the ensemble classifier using the extracted features
#ensemble_classifier.fit(X_train_combined, Y_train) #Y_train

# %%
#X_val_combined = X_val_combined.reshape(X_val_combined.shape[0], X_val_combined.shape[1]*X_val_combined.shape[2])

#y_pred = ensemble_classifier.predict(X_val_combined)

# %% [markdown]
# # Experiment 7 - Raw Signal -> DL Model for Feature Selection and DL Classifier

# %%
def create_cnn_lstm_attention(input_shape):
    # Input layer
    input_layer = Input(shape=input_shape)

    # Convolutional layer for local feature extraction
    conv1 = Conv1D(filters=256, kernel_size=3, activation='relu')(input_layer)
    conv2 = Conv1D(filters=256, kernel_size=5, activation='relu')(conv1)
    conv3 = Conv1D(filters=256, kernel_size=3, activation='relu')(conv2)
    pool1 = MaxPooling1D(pool_size=2)(conv3)

    # LSTM layer for capturing temporal features
    lstm1 = LSTM(units=256, return_sequences=True)(pool1)
    lstm2 = LSTM(units=256, return_sequences=True)(lstm1)
    lstm3 = LSTM(units=512, return_sequences=True)(lstm2)
    lstm4 = LSTM(units=512, return_sequences=True)(lstm3)
    # Attention mechanism to focus on relevant temporal features
    attention = Attention()([lstm3, lstm3])
    pool2 = MaxPooling1D(pool_size=2)(attention)
    # Flatten the output from LSTM and attention layers
    flatten = Flatten()(pool2)

    # Fully connected layer for classification or further processing
    dense_layer = Dense(996, activation='relu')(flatten)
    # Create the model
    model = Model(inputs=input_layer, outputs=dense_layer)
    return model

# %%
input_shape = X_train.shape[1:]
cnn_lstm_model = create_cnn_lstm_attention(input_shape)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']

# %%
history = compile_and_fit(cnn_lstm_model,"expt7_cnn_lstm_model",optimizer='adam',epochs=50,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 12, 365)]    0           []
#
#  conv1d_42 (Conv1D)             (None, 10, 256)      280576      ['input_5[0][0]']
#
#  conv1d_43 (Conv1D)             (None, 6, 256)       327936      ['conv1d_42[0][0]']
#
#  conv1d_44 (Conv1D)             (None, 4, 256)       196864      ['conv1d_43[0][0]']
#
#  max_pooling1d_16 (MaxPooling1D  (None, 2, 256)      0           ['conv1d_44[0][0]']
#  )
#
#  lstm_3 (LSTM)                  (None, 2, 256)       525312      ['max_pooling1d_16[0][0]']
#
#  lstm_4 (LSTM)                  (None, 2, 256)       525312      ['lstm_3[0][0]']
#
#  lstm_5 (LSTM)                  (None, 2, 512)       1574912     ['lstm_4[0][0]']
#
#  attention (Attention)          (None, 2, 512)       0           ['lstm_5[0][0]',
#                                                                   'lstm_5[0][0]']
#
#  max_pooling1d_17 (MaxPooling1D  (None, 1, 512)      0           ['attention[0][0]']
#  )
#
#  flatten_2 (Flatten)            (None, 512)          0           ['max_pooling1d_17[0][0]']
#
#  dense_16 (Dense)               (None, 996)          510948      ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 3,941,860
# Trainable params: 3,941,860
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/50
# 44/44 [==============================] - 27s 458ms/step - loss: 1.4812 - accuracy: 0.5390 - val_loss: 1.2886 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/50
# 44/44 [==============================] - 16s 364ms/step - loss: 1.2594 - accuracy: 0.5547 - val_loss: 1.2657 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/50
# 44/44 [==============================] - 16s 360ms/step - loss: 1.2461 - accuracy: 0.5555 - val_loss: 1.2494 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/50
# 44/44 [==============================] - 16s 362ms/step - loss: 1.2623 - accuracy: 0.5563 - val_loss: 1.2808 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/50
# 44/44 [==============================] - 16s 357ms/step - loss: 1.2383 - accuracy: 0.5536 - val_loss: 1.2587 - val_accuracy: 0.5557 - lr: 0.0010
# Epoch 6/50
# 44/44 [==============================] - 16s 365ms/step - loss: 1.2209 - accuracy: 0.5571 - val_loss: 1.2487 - val_accuracy: 0.5511 - lr: 0.0010
# Epoch 7/50
# 44/44 [==============================] - 16s 366ms/step - loss: 1.2104 - accuracy: 0.5631 - val_loss: 1.2482 - val_accuracy: 0.5514 - lr: 0.0010
# Epoch 8/50
# 44/44 [==============================] - 16s 361ms/step - loss: 1.2080 - accuracy: 0.5684 - val_loss: 1.2208 - val_accuracy: 0.5664 - lr: 0.0010
# Epoch 9/50
# 44/44 [==============================] - 16s 370ms/step - loss: 1.2234 - accuracy: 0.5743 - val_loss: 1.2466 - val_accuracy: 0.5677 - lr: 0.0010
# Epoch 10/50
# 44/44 [==============================] - 16s 369ms/step - loss: 1.1804 - accuracy: 0.5783 - val_loss: 1.4995 - val_accuracy: 0.4417 - lr: 0.0010
# Epoch 11/50
# 44/44 [==============================] - 16s 361ms/step - loss: 1.2649 - accuracy: 0.5623 - val_loss: 1.2341 - val_accuracy: 0.5589 - lr: 0.0010
# Epoch 12/50
# 44/44 [==============================] - 16s 359ms/step - loss: 1.1866 - accuracy: 0.5774 - val_loss: 1.2540 - val_accuracy: 0.5752 - lr: 2.0000e-04
# Epoch 13/50
# 44/44 [==============================] - 16s 361ms/step - loss: 1.2141 - accuracy: 0.5589 - val_loss: 1.2245 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 14/50
# 44/44 [==============================] - 16s 363ms/step - loss: 1.1890 - accuracy: 0.5581 - val_loss: 1.1955 - val_accuracy: 0.5674 - lr: 2.0000e-04
# Epoch 15/50
# 44/44 [==============================] - 16s 366ms/step - loss: 1.1712 - accuracy: 0.5851 - val_loss: 1.1815 - val_accuracy: 0.5833 - lr: 2.0000e-04
# Epoch 16/50
# 44/44 [==============================] - 16s 353ms/step - loss: 1.1462 - accuracy: 0.5938 - val_loss: 1.1822 - val_accuracy: 0.5817 - lr: 2.0000e-04
- val_accuracy: 0.5918 - lr: 1.0000e-04
# Epoch 37/50
# 44/44 [==============================] - 15s 352ms/step - loss: 0.9919 - accuracy: 0.6455 - val_loss: 1.4377 - val_accuracy: 0.5986 - lr: 1.0000e-04
# Epoch 38/50
# 44/44 [==============================] - 16s 368ms/step - loss: 0.9707 - accuracy: 0.6452 - val_loss: 1.4583 - val_accuracy: 0.5934 - lr: 1.0000e-04
# Epoch 39/50
# 44/44 [==============================] - 15s 352ms/step - loss: 0.9366 - accuracy: 0.6544 - val_loss: 1.5070 - val_accuracy: 0.5918 - lr: 1.0000e-04
# Epoch 40/50
# 44/44 [==============================] - 16s 368ms/step - loss: 0.9240 - accuracy: 0.6613 - val_loss: 1.5754 - val_accuracy: 0.5905 - lr: 1.0000e-04
# Epoch 41/50
# 44/44 [==============================] - 15s 351ms/step - loss: 0.9103 - accuracy: 0.6680 - val_loss: 1.6001 - val_accuracy: 0.5898 - lr: 1.0000e-04
# Epoch 42/50
# 44/44 [==============================] - 16s 365ms/step - loss: 0.9242 - accuracy: 0.6610 - val_loss: 1.5063 - val_accuracy: 0.5876 - lr: 1.0000e-04
# Epoch 43/50
# 44/44 [==============================] - 16s 366ms/step - loss: 0.9302 - accuracy: 0.6659 - val_loss: 1.5112 - val_accuracy: 0.5944 - lr: 1.0000e-04
# Epoch 44/50
# 44/44 [==============================] - 16s 353ms/step - loss: 0.9193 - accuracy: 0.6687 - val_loss: 1.5830 - val_accuracy: 0.5905 - lr: 1.0000e-04
# Epoch 45/50
# 44/44 [==============================] - 16s 373ms/step - loss: 0.9375 - accuracy: 0.6578 - val_loss: 1.2826 - val_accuracy: 0.5771 - lr: 1.0000e-04
# Epoch 46/50
# 44/44 [==============================] - 15s 348ms/step - loss: 0.9745 - accuracy: 0.6547 - val_loss: 1.2888 - val_accuracy: 0.5980 - lr: 1.0000e-04
# Epoch 47/50
# 44/44 [==============================] - 16s 366ms/step - loss: 0.9356 - accuracy: 0.6668 - val_loss: 1.4146 - val_accuracy: 0.5928 - lr: 1.0000e-04
# Epoch 48/50
# 44/44 [==============================] - 16s 369ms/step - loss: 0.8963 - accuracy: 0.6763 - val_loss: 1.5701 - val_accuracy: 0.5918 - lr: 1.0000e-04
# Epoch 49/50
# 44/44 [==============================] - 15s 350ms/step - loss: 0.8739 - accuracy: 0.6807 - val_loss: 1.6574 - val_accuracy: 0.5895 - lr: 1.0000e-04
# Epoch 50/50
# 44/44 [==============================] - 16s 363ms/step - loss: 0.8581 - accuracy: 0.6880 - val_loss: 1.6893 - val_accuracy: 0.5911 - lr: 1.0000e-04

# %%
X_train_features_DL = cnn_lstm_model.predict(X_train)
print(f"Shape of Features extracted from DL {X_train_features_DL.shape}")
# Out:
# 354/354 [==============================] - 8s 17ms/step
# Shape of Features extracted from DL (11297, 996)

# %%
X_val_features_DL = cnn_lstm_model.predict(X_val)
print(f"Shape of Features extracted from DL {X_val_features_DL.shape}")
# Out:
# 103/103 [==============================] - 2s 18ms/step
# Shape of Features extracted from DL (3268, 996)

# %%
X_train_features_DL = X_train_features_DL.reshape(X_train_features_DL.shape[0], 12, int(X_train_features_DL.shape[1]/12))
X_val_features_DL = X_val_features_DL.reshape(X_val_features_DL.shape[0], 12, int(X_val_features_DL.shape[1]/12))

print(f"Shape of Features Reshaped from DL {X_train_features_DL.shape}")
print(f"Shape of Features Reshaped from DL {X_val_features_DL.shape}")
# Out:
# Shape of Features Reshaped from DL (11297, 12, 83)
# Shape of Features Reshaped from DL (3268, 12, 83)

# %%
X_test = cnn_lstm_model.predict(X_test)
print(f"Shape of Features extracted from DL {X_test.shape}")
# Out:
# 53/53 [==============================] - 1s 18ms/step
# Shape of Features extracted from DL (1670, 996)

# %%
X_test = X_test.reshape(X_test.shape[0], 12, int(X_test.shape[1]/12))

# %%
train_ds = create_dataset(X_train_features_DL, Y_train)
val_ds = create_dataset(X_val_features_DL, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 83)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 83)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train_features_DL.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
history = compile_and_fit(conv1d_mha_model,"expt6_FS_cnn_mha_model",optimizer='adam',epochs=15,batch_size=128,learning_rate=0.001)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 12, 83)]     0           []
#
#  conv1d_45 (Conv1D)             (None, 12, 32)       2688        ['input_6[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 12, 32)      128         ['conv1d_45[0][0]']
#  ormalization)
#
#  conv1d_46 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 12, 64)      256         ['conv1d_46[0][0]']
#  ormalization)
#
#  max_pooling1d_18 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_29[0][0]']
#  )
#
#  dropout_20 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_18[0][0]']
#
#  conv1d_47 (Conv1D)             (None, 12, 128)      8320        ['dropout_20[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 12, 128)     512         ['conv1d_47[0][0]']
#  ormalization)
#
#  dropout_21 (Dropout)           (None, 12, 128)      0           ['batch_normalization_30[0][0]']
#
#  conv1d_48 (Conv1D)             (None, 12, 128)      16512       ['dropout_21[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 12, 128)     512         ['conv1d_48[0][0]']
#  ormalization)
#
#  max_pooling1d_19 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_31[0][0]']
#  )
#
#  conv1d_49 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_19[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 12, 512)     2048        ['conv1d_49[0][0]']
#  ormalization)
#
#  conv1d_50 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_32[0][0]']
#
#  multi_head_attention_4 (MultiH  (None, 12, 512)     31277       ['conv1d_50[0][0]',
#  eadAttention)                                                    'conv1d_50[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_4[0][0]']
#  rmalization)
#
#  concatenate_4 (Concatenate)    (None, 12, 1024)     0           ['conv1d_50[0][0]',
#                                                                   'layer_normalization_4[0][0]']
#
#  global_average_pooling1d_5 (Gl  (None, 1024)        0           ['concatenate_4[0][0]']
#  obalAveragePooling1D)
#
#  dropout_22 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_5[0][0
#                                                                  ]']
#
#  dense_17 (Dense)               (None, 256)          262400      ['dropout_22[0][0]']
#
#  dropout_23 (Dropout)           (None, 256)          0           ['dense_17[0][0]']
#
#  dense_18 (Dense)               (None, 128)          32896       ['dropout_23[0][0]']
#
#  dense_19 (Dense)               (None, 5)            645         ['dense_18[0][0]']
#
# ==================================================================================================
# Total params: 690,034
# Trainable params: 688,306
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/15
# 44/44 [==============================] - 17s 276ms/step - loss: 1.1016 - accuracy: 0.6294 - val_loss: 1.3369 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/15
# 44/44 [==============================] - 12s 271ms/step - loss: 0.9511 - accuracy: 0.6744 - val_loss: 1.3443 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/15
# 44/44 [==============================] - 12s 265ms/step - loss: 0.9354 - accuracy: 0.6780 - val_loss: 1.4223 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/15
# 44/44 [==============================] - 12s 269ms/step - loss: 0.9285 - accuracy: 0.6740 - val_loss: 1.3363 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/15
# 44/44 [==============================] - 12s 273ms/step - loss: 0.9224 - accuracy: 0.6772 - val_loss: 1.3197 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/15
# 44/44 [==============================] - 12s 271ms/step - loss: 0.9176 - accuracy: 0.6787 - val_loss: 1.3705 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/15
# 44/44 [==============================] - 12s 265ms/step - loss: 0.9171 - accuracy: 0.6762 - val_loss: 1.3282 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/15
# 44/44 [==============================] - 12s 272ms/step - loss: 0.9026 - accuracy: 0.6812 - val_loss: 1.2953 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/15
# 44/44 [==============================] - 12s 269ms/step - loss: 0.9068 - accuracy: 0.6841 - val_loss: 1.3026 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 10/15
# 44/44 [==============================] - 12s 274ms/step - loss: 0.8980 - accuracy: 0.6807 - val_loss: 1.2722 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 11/15
# 44/44 [==============================] - 12s 275ms/step - loss: 0.8951 - accuracy: 0.6846 - val_loss: 1.2771 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 12/15
# 44/44 [==============================] - 12s 272ms/step - loss: 0.8898 - accuracy: 0.6817 - val_loss: 1.2386 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 13/15
# 44/44 [==============================] - 12s 274ms/step - loss: 0.8884 - accuracy: 0.6867 - val_loss: 1.2114 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 14/15
# 44/44 [==============================] - 12s 276ms/step - loss: 0.8892 - accuracy: 0.6818 - val_loss: 1.2090 - val_accuracy: 0.5553 - lr: 0.0010
# Epoch 15/15
# 44/44 [==============================] - 12s 273ms/step - loss: 0.8801 - accuracy: 0.6858 - val_loss: 1.2112 - val_accuracy: 0.5592 - lr: 0.0010

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5479041916167665
# Precision of the Model is 0.5133266221567561
# Recall of the Model is 0.5479041916167665
# F1 Score of the Model is 0.40356789706802937

# %% [markdown]
# # Experiment 8 - DL Model (FE) + FS

# %%
X_train, Y_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
cnn_lstm_model = create_cnn_lstm_attention(input_shape)

# %%
X_train.shape
# Out:
# (11297, 12, 1000)

# %%
X_train_features_DL = cnn_lstm_model.predict(X_train)
print(f"Shape of Features extracted from DL {X_train_features_DL.shape}")
# Out:
# 354/354 [==============================] - 9s 20ms/step
# Shape of Features extracted from DL (11297, 996)

# %%
X_val_features_DL = cnn_lstm_model.predict(X_val)
print(f"Shape of Features extracted from DL {X_val_features_DL.shape}")
# Out:
# 103/103 [==============================] - 2s 20ms/step
# Shape of Features extracted from DL (3268, 996)

# %%
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
X_val.shape
# Out:
# (3268, 12, 1000)

# %%
X_test_features_DL = cnn_lstm_model.predict(X_test)
print(f"Shape of Features extracted from DL {X_test_features_DL.shape}")
# Out:
# 53/53 [==============================] - 1s 20ms/step
# Shape of Features extracted from DL (1670, 996)

# %%
X_train_features_DL = X_train_features_DL.reshape(X_train_features_DL.shape[0], 12, int(X_train_features_DL.shape[1]/12))
X_val_features_DL = X_val_features_DL.reshape(X_val_features_DL.shape[0], 12, int(X_val_features_DL.shape[1]/12))
X_test_features_DL = X_test_features_DL.reshape(X_test_features_DL.shape[0], 12, int(X_test_features_DL.shape[1]/12))

print(f"Shape of Features Reshaped from DL {X_train_features_DL.shape}")
print(f"Shape of Features Reshaped from DL {X_val_features_DL.shape}")
print(f"Shape of Features Reshaped from DL {X_test_features_DL.shape}")
# Out:
# Shape of Features Reshaped from DL (11297, 12, 83)
# Shape of Features Reshaped from DL (3268, 12, 83)
# Shape of Features Reshaped from DL (1670, 12, 83)

# %%
X_train_Fs, Y_train_Fs = load_data('/kaggle/input/fe-all/X_AllFeatures_train.npz', 'train')
X_val_Fs, Y_val_Fs = load_data('/kaggle/input/fe-all/X_AllFeatures_val.npz','val')
X_test_Fs, Y_test_Fs = load_data('/kaggle/input/fe-all/X_AllFeatures_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 365),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 365),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 365),  (1670,)

# %%
X_train_combined = np.concatenate((X_train_features_DL, X_train_Fs), axis=2)
X_val_combined = np.concatenate((X_val_features_DL, X_val_Fs), axis=2)
X_test_combined = np.concatenate((X_test_features_DL, X_test_Fs), axis=2)


print(f"Shape of Features Reshaped from DL {X_train_combined.shape}")
print(f"Shape of Features Reshaped from DL {X_val_combined.shape}")
print(f"Shape of Features Reshaped from DL {X_test_combined.shape}")
# Out:
# Shape of Features Reshaped from DL (11297, 12, 448)
# Shape of Features Reshaped from DL (3268, 12, 448)
# Shape of Features Reshaped from DL (1670, 12, 448)

# %%
input_shape = X_train_combined.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
train_ds = create_dataset(X_train_combined, Y_train)
val_ds = create_dataset(X_val_combined, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 448)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 448)', 'Shape of Batched Dataset (256,)']

# %%
history = compile_and_fit(conv1d_mha_model,"expt_FS_cnn_mha_combined_model",optimizer='adam',epochs=100,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 12, 448)]    0           []
#
#  conv1d_54 (Conv1D)             (None, 12, 32)       14368       ['input_8[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 12, 32)      128         ['conv1d_54[0][0]']
#  ormalization)
#
#  conv1d_55 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 12, 64)      256         ['conv1d_55[0][0]']
#  ormalization)
#
#  max_pooling1d_22 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_34[0][0]']
#  )
#
#  dropout_24 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_22[0][0]']
#
#  conv1d_56 (Conv1D)             (None, 12, 128)      8320        ['dropout_24[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 12, 128)     512         ['conv1d_56[0][0]']
#  ormalization)
#
#  dropout_25 (Dropout)           (None, 12, 128)      0           ['batch_normalization_35[0][0]']
#
#  conv1d_57 (Conv1D)             (None, 12, 128)      16512       ['dropout_25[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 12, 128)     512         ['conv1d_57[0][0]']
#  ormalization)
#
#  max_pooling1d_23 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_36[0][0]']
#  )
#
#  conv1d_58 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_23[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 12, 512)     2048        ['conv1d_58[0][0]']
#  ormalization)
#
#  conv1d_59 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_37[0][0]']
#
#  multi_head_attention_5 (MultiH  (None, 12, 512)     31277       ['conv1d_59[0][0]',
#  eadAttention)                                                    'conv1d_59[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_5[0][0]']
#  rmalization)
#
#  concatenate_5 (Concatenate)    (None, 12, 1024)     0           ['conv1d_59[0][0]',
#                                                                   'layer_normalization_5[0][0]']
#
#  global_average_pooling1d_6 (Gl  (None, 1024)        0           ['concatenate_5[0][0]']
#  obalAveragePooling1D)
#
#  dropout_26 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_6[0][0
#                                                                  ]']
#
#  dense_21 (Dense)               (None, 256)          262400      ['dropout_26[0][0]']
#
#  dropout_27 (Dropout)           (None, 256)          0           ['dense_21[0][0]']
#
#  dense_22 (Dense)               (None, 128)          32896       ['dropout_27[0][0]']
#
#  dense_23 (Dense)               (None, 5)            645         ['dense_22[0][0]']
#
# ==================================================================================================
# Total params: 701,714
# Trainable params: 699,986
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 18s 286ms/step - loss: 1.3534 - accuracy: 0.5253 - val_loss: 1.3979 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 13s 285ms/step - loss: 1.2603 - accuracy: 0.5543 - val_loss: 1.3495 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] - 12s 274ms/step - loss: 1.2346 - accuracy: 0.5596 - val_loss: 1.3165 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/100
# 44/44 [==============================] - 12s 273ms/step - loss: 1.2032 - accuracy: 0.5652 - val_loss: 1.3081 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/100
# 44/44 [==============================] - 12s 283ms/step - loss: 1.1904 - accuracy: 0.5702 - val_loss: 1.3745 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.1654 - accuracy: 0.5757 - val_loss: 1.3556 - val_accuracy: 0.5596 - lr: 0.0010
# Epoch 7/100
# 44/44 [==============================] - 12s 271ms/step - loss: 1.1527 - accuracy: 0.5751 - val_loss: 1.3235 - val_accuracy: 0.5547 - lr: 0.0010
# Epoch 8/100
# 44/44 [==============================] - 13s 287ms/step - loss: 1.1210 - accuracy: 0.5800 - val_loss: 1.2550 - val_accuracy: 0.5648 - lr: 2.0000e-04
# Epoch 9/100
# 44/44 [==============================] - 12s 271ms/step - loss: 1.1101 - accuracy: 0.5882 - val_loss: 1.2124 - val_accuracy: 0.5703 - lr: 2.0000e-04
# Epoch 10/100
# 44/44 [==============================] - 12s 284ms/step - loss: 1.0946 - accuracy: 0.5905 - val_loss: 1.1991 - val_accuracy: 0.5811 - lr: 2.0000e-04
# Epoch 11/100
# 44/44 [==============================] - 12s 273ms/step - loss: 1.0892 - accuracy: 0.5921 - val_loss: 1.1788 - val_accuracy: 0.5846 - lr: 2.0000e-04
# Epoch 12/100
# 44/44 [==============================] - 12s 270ms/step - loss: 1.0853 - accuracy: 0.6002 - val_loss: 1.1602 - val_accuracy: 0.5824 - lr: 2.0000e-04
# Epoch 13/100
# 44/44 [==============================] - 12s 280ms/step - loss: 1.0782 - accuracy: 0.5976 - val_loss: 1.1561 - val_accuracy: 0.5853 - lr: 2.0000e-04
# Epoch 14/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.0750 - accuracy: 0.5995 - val_loss: 1.1535 - val_accuracy: 0.5853 - lr: 2.0000e-04
# Epoch 15/100
# 44/44 [==============================] - 12s 279ms/step - loss: 1.0678 - accuracy: 0.6024 - val_loss: 1.1454 - val_accuracy: 0.5876 - lr: 2.0000e-04
# Epoch 16/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.0687 - accuracy: 0.6041 - val_loss: 1.1416 - val_accuracy: 0.5895 - lr: 2.0000e-04
# Epoch 17/100
# 44/44 [==============================] - 12s 281ms/step - loss: 1.0600 - accuracy: 0.6075 - val_loss: 1.1403 - val_accuracy: 0.5895 - lr: 2.0000e-04
# Epoch 18/100
# 44/44 [==============================] - 12s 281ms/step - loss: 1.0553 - accuracy: 0.6136 - val_loss: 1.1458 - val_accuracy: 0.5905 - lr: 2.0000e-04
# Epoch 19/100
# 44/44 [==============================] - 12s 278ms/step - loss: 1.0493 - accuracy: 0.6106 - val_loss: 1.1280 - val_accuracy: 0.5934 - lr: 2.0000e-04
# Epoch 20/100
# 44/44 [==============================] - 12s 275ms/step - loss: 1.0532 - accuracy: 0.6096 - val_loss: 1.1341 - val_accuracy: 0.5960 - lr: 2.0000e-04
# Epoch 21/100
# 44/44 [==============================] - 12s 281ms/step - loss: 1.0362 - accuracy: 0.6101 - val_loss: 1.1248 - val_accuracy: 0.5931 - lr: 2.0000e-04
# Epoch 22/100
# 44/44 [==============================] - 12s 268ms/step - loss: 1.0370 - accuracy: 0.6156 - val_loss: 1.1301 - val_accuracy: 0.5908 - lr: 2.0000e-04
# Epoch 23/100
# 44/44 [==============================] - 12s 282ms/step - loss: 1.0366 - accuracy: 0.6145 - val_loss: 1.1329 - val_accuracy: 0.5924 - lr: 2.0000e-04
# Epoch 24/100
# 44/44 [==============================] - 12s 273ms/step - loss: 1.0284 - accuracy: 0.6223 - val_loss: 1.1295 - val_accuracy: 0.5938 - lr: 2.0000e-04
# Epoch 25/100
# 44/44 [==============================] - 13s 287ms/step - loss: 1.0203 - accuracy: 0.6223 - val_loss: 1.1233 - val_accuracy: 0.5977 - lr: 1.0000e-04
# Epoch 26/100
# 44/44 [==============================] - 12s 275ms/step - loss: 1.
100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9552 - accuracy: 0.6485 - val_loss: 1.1266 - val_accuracy: 0.5872 - lr: 1.0000e-04
# Epoch 49/100
# 44/44 [==============================] - 12s 280ms/step - loss: 0.9513 - accuracy: 0.6515 - val_loss: 1.1312 - val_accuracy: 0.5859 - lr: 1.0000e-04
# Epoch 50/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.9451 - accuracy: 0.6509 - val_loss: 1.1275 - val_accuracy: 0.5837 - lr: 1.0000e-04
# Epoch 51/100
# 44/44 [==============================] - 12s 279ms/step - loss: 0.9430 - accuracy: 0.6556 - val_loss: 1.1306 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 52/100
# 44/44 [==============================] - 12s 268ms/step - loss: 0.9482 - accuracy: 0.6516 - val_loss: 1.1319 - val_accuracy: 0.5820 - lr: 1.0000e-04
# Epoch 53/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.9469 - accuracy: 0.6525 - val_loss: 1.1396 - val_accuracy: 0.5794 - lr: 1.0000e-04
# Epoch 54/100
# 44/44 [==============================] - 12s 275ms/step - loss: 0.9411 - accuracy: 0.6524 - val_loss: 1.1332 - val_accuracy: 0.5768 - lr: 1.0000e-04
# Epoch 55/100
# 44/44 [==============================] - 12s 282ms/step - loss: 0.9355 - accuracy: 0.6608 - val_loss: 1.1355 - val_accuracy: 0.5807 - lr: 1.0000e-04
# Epoch 56/100
# 44/44 [==============================] - 12s 281ms/step - loss: 0.9340 - accuracy: 0.6562 - val_loss: 1.1417 - val_accuracy: 0.5794 - lr: 1.0000e-04
# Epoch 57/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.9369 - accuracy: 0.6588 - val_loss: 1.1474 - val_accuracy: 0.5771 - lr: 1.0000e-04
# Epoch 58/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9286 - accuracy: 0.6582 - val_loss: 1.1450 - val_accuracy: 0.5811 - lr: 1.0000e-04
# Epoch 59/100
# 44/44 [==============================] - 12s 284ms/step - loss: 0.9183 - accuracy: 0.6645 - val_loss: 1.1450 - val_accuracy: 0.5872 - lr: 1.0000e-04
# Epoch 60/100
# 44/44 [==============================] - 12s 271ms/step - loss: 0.9231 - accuracy: 0.6622 - val_loss: 1.1437 - val_accuracy: 0.5837 - lr: 1.0000e-04
# Epoch 61/100
# 44/44 [==============================] - 12s 276ms/step - loss: 0.9204 - accuracy: 0.6645 - val_loss: 1.1477 - val_accuracy: 0.5817 - lr: 1.0000e-04
# Epoch 62/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.9132 - accuracy: 0.6664 - val_loss: 1.1466 - val_accuracy: 0.5833 - lr: 1.0000e-04
# Epoch 63/100
# 44/44 [==============================] - 12s 280ms/step - loss: 0.9180 - accuracy: 0.6588 - val_loss: 1.1520 - val_accuracy: 0.5798 - lr: 1.0000e-04
# Epoch 64/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.9109 - accuracy: 0.6661 - val_loss: 1.1421 - val_accuracy: 0.5853 - lr: 1.0000e-04
# Epoch 65/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.9097 - accuracy: 0.6665 - val_loss: 1.1493 - val_accuracy: 0.5765 - lr: 1.0000e-04
# Epoch 66/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.9080 - accuracy: 0.6667 - val_loss: 1.1576 - val_accuracy: 0.5775 - lr: 1.0000e-04
# Epoch 67/100
# 44/44 [==============================] - 12s 280ms/step - loss: 0.9017 - accuracy: 0.6710 - val_loss: 1.1476 - val_accuracy: 0.5765 - lr: 1.0000e-04
# Epoch 68/100
# 44/44 [==============================] - 12s 275ms/step - loss: 0.9016 - accuracy: 0.6703 - val_loss: 1.1500 - val_accuracy: 0.5762 - lr: 1.0000e-04
# Epoch 69/100
# 44/44 [==============================] - 12s 278ms/step - loss: 0.8996 - accuracy: 0.6677 - val_loss: 1.1494 - val_accuracy: 0.5752 - lr: 1.0000e-04
# Epoch 70/100
# 44/44 [==============================] - 12s 276ms/step - loss: 0.8992 - accuracy: 0.6705 - val_loss: 1.1473 - val_accuracy: 0.5798 - lr: 1.0000e-04
# Epoch 71/100
# 44/44 [==============================] - 12s 281ms/step - loss: 0.8990 - accuracy: 0.6700 - val_loss: 1.1516 - val_accuracy: 0.5794 - lr: 1.0000e-04
# Epoch 72/100
# 44/44 [==============================] - 12s 276ms/step - loss: 0.8826 - accuracy: 0.6769 - val_loss: 1.1546 - val_accuracy: 0.5726 - lr: 1.0000e-04
# Epoch 73/100
# 44/44 [==============================] - 12s 279ms/step - loss: 0.8929 - accuracy: 0.6752 - val_loss: 1.1498 - val_accuracy: 0.5768 - lr: 1.0000e-04
# Epoch 74/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.8940 - accuracy: 0.6716 - val_loss: 1.1505 - val_accuracy: 0.5785 - lr: 1.0000e-04
# Epoch 75/100
# 44/44 [==============================] - 12s 277ms/step - loss: 0.8897 - accuracy: 0.6702 - val_loss: 1.1525 - val_accuracy: 0.5752 - lr: 1.0000e-04
# Epoch 76/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.8862 - accuracy: 0.6768 - val_loss: 1.1636 - val_accuracy: 0.5768 - lr: 1.0000e-04
# Epoch 77/100
# 44/44 [==============================] - 13s 286ms/step - loss: 0.8755 - accuracy: 0.6768 - val_loss: 1.1602 - val_accuracy: 0.5745 - lr: 1.0000e-04
# Epoch 78/100
# 44/44 [==============================] - 12s 272ms/step - loss: 0.8786 - accuracy: 0.6784 - val_loss: 1.1848 - val_accuracy: 0.5710 - lr: 1.0000e-04
# Epoch 79/100
# 44/44 [==============================] - 12s 280ms/step - loss: 0.8813 - accuracy: 0.6741 - val_loss: 1.1618 - val_accuracy: 0.5755 - lr: 1.0000e-04
# Epoch 80/100
# 44/44 [==============================] - 12s 273ms/step - loss: 0.8749 - accuracy: 0.6744 - val_loss: 1.1808 - val_accuracy: 0.5710 - lr: 1.0000e-04
# Epoch 81/100
# 44/44 [==============================] - 12s 284ms/step - loss: 0.8685 - accuracy: 0.6845 - val_loss: 1.1638 - val_accuracy: 0.5687 - lr: 1.0000e-04
# Epoch 82/100
# 44/44 [==============================] - 12s 267ms/step - loss: 0.8625 - accuracy: 0.6822 - val_loss: 1.1723 - val_accuracy: 0.5742 - lr: 1.0000e-04
# Epoch 82: early stopping

# %%
#display_output(, history, X_test_combined)

Y_pred = conv1d_mha_model.predict(X_test_combined)
# Out:
# 53/53 [==============================] - 1s 10ms/step

# %%
# Evaluate the model
evaluation = evaluate_model(conv1d_mha_model, Y_test, x_test= X_test_combined)

#plot the history loss
plot_loss(history)

# Access individual evaluation metrics
confusion = evaluation['confusion_matrix']
report = evaluation['classification_report']
print(f"Accuracy of the Model is  {evaluation['accuracy']}")
print (f"Precision of the Model is {evaluation['precision']}")
print (f"Recall of the Model is {evaluation['recall']}")
print(f"F1 Score of the Model is {evaluation['f1_score']}")
#auc = evaluation['auc']
#num_parameters = evaluation['num_parameters']

#plot the confusion matrix and classification report
plot_confusion_matrix(confusion)
plot_classification_report(report)

plot_roc_curves(Y_test, Y_pred)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5706586826347305
# Precision of the Model is 0.514721547060766
# Recall of the Model is 0.5706586826347305
# F1 Score of the Model is 0.5329318841995226
