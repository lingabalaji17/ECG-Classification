# %%
import pandas as pd
import numpy as np
import os
import wfdb
import ast

import tensorflow as tf
from tensorflow import keras
#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
#sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# # Loading Data

# %%
'''function to load the data from the saved file path for different experiments. 
    Saved Data for future use and for conducting experiments as extracting data is resource intensive'''
def load_data(filepath, type, x_key='x', y_key='y'):
    # Load X_test and Y_test
    data = np.load(filepath)
    x = data[x_key]
    y = data[y_key]

    print (f"Shape of X-{type} and Y_{type} : {x.shape},  {y.shape}")
    return x, y

# %%
'''function to create dataset from the numpy array'''
def create_dataset(x, y, batch_size=256):
    dataset_X = tf.data.Dataset.from_tensor_slices(x)
    dataset_Y = tf.data.Dataset.from_tensor_slices(y)
    dataset =  tf.data.Dataset.zip((dataset_X, dataset_Y))

    ds = dataset.batch(batch_size, drop_remainder=True)

    for batch in ds.take(1):
        print([f"Shape of Batched Dataset {arr.numpy().shape}" for arr in batch])
    
    return ds

# %% [markdown]
# # Utils functions for Building and Evaluating Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, MultiHeadAttention, Dense, Flatten, Input,GlobalAveragePooling1D, BatchNormalization,MaxPooling1D,Attention,LayerNormalization, Dropout,Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_recall_fscore_support, roc_auc_score

def evaluate_model(model, X_test, Y_test):
    # Predict labels for the test set
   # Get the predicted probabilities
    Y_pred_prob = model.predict(X_test)

    # Convert the predicted probabilities to class labels
    Y_pred = np.argmax(Y_pred_prob, axis=1)

    # Calculate evaluation metrics
    confusion = confusion_matrix(Y_test, Y_pred)
    report = classification_report(Y_test, Y_pred)
    accuracy = accuracy_score(Y_test, Y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(Y_test, Y_pred, average='weighted')
    #auc = roc_auc_score(Y_test, Y_pred)
    #num_parameters = model.count_params()  # Replace with the appropriate method to count model parameters

    # Create a dictionary of evaluation metrics
    evaluation = {
        'confusion_matrix': confusion,
        'classification_report': report,
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        #'auc': auc,
        #'num_parameters': num_parameters
    }

    return evaluation

# %%
import seaborn as sns

def plot_confusion_matrix(confusion):
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion, annot=True, cmap='Blues', fmt='g')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

def plot_classification_report(report):
    # Extract precision, recall, and F1-score from the report
    lines = report.split('\n')[2:-5]
    classes = []
    precision = []
    recall = []
    f1_score = []
    for line in lines:
        row = line.split()
        classes.append(row[0])
        precision.append(float(row[1]))
        recall.append(float(row[2]))
        f1_score.append(float(row[3]))

    # Plot precision, recall, and F1-score
    plt.figure(figsize=(10, 4))
    plt.bar(classes, precision, label='Precision')
    plt.bar(classes, recall, label='Recall')
    plt.bar(classes, f1_score, label='F1-Score')
    plt.xlabel('Classes')
    plt.ylabel('Scores')
    plt.title('Classification Report')
    plt.legend()
    plt.show()
    
def plot_loss(history):
    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from itertools import cycle

def plot_roc_curves(Y_test, Y_scores):
    # Compute the number of classes
    num_classes = len(np.unique(Y_test))

    # Compute the fpr, tpr, and roc_auc for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(Y_test == i, Y_scores[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curves for each class
    plt.figure(figsize=(8, 6))

    colors = cycle(['blue', 'red', 'green', 'orange', 'purple'])
    classes = [f'Class {i}' for i in range(num_classes)]

    for i, color in zip(range(num_classes), colors):
        plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f'ROC curve of {classes[i]} (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC)')
    plt.legend(loc='lower right')
    plt.show()

# %%
def display_output(model, history):

    Y_pred = model.predict(X_test)
    # Evaluate the model
    evaluation = evaluate_model(model, X_test, Y_test)
    
    #plot the history loss
    plot_loss(history)
    
    # Access individual evaluation metrics
    confusion = evaluation['confusion_matrix']
    report = evaluation['classification_report']
    print(f"Accuracy of the Model is  {evaluation['accuracy']}")
    print (f"Precision of the Model is {evaluation['precision']}")
    print (f"Recall of the Model is {evaluation['recall']}")
    print(f"F1 Score of the Model is {evaluation['f1_score']}")
    #auc = evaluation['auc']
    #num_parameters = evaluation['num_parameters']

    #plot the confusion matrix and classification report
    plot_confusion_matrix(confusion)
    plot_classification_report(report)

    plot_roc_curves(Y_test, Y_pred)

# %%
def get_optimizer(optimizer, learning_rate):
    if(optimizer=="adam"):
        return tf.keras.optimizers.Adam(learning_rate)
    elif (optimizer=="sgd"):
        return tf.keras.optimizers.SGD(learning_rate)
    elif (optimizer=="rmsprop"):
        return tf.keras.optimizers.RMSprop(learning_rate)
    elif (optimizer=="nadam"):
        return tf.keras.optimizers.Nadam(learning_rate)
    elif (optimizer=="adagrad"):
        return tf.keras.optimizers.Adagrad(learning_rate)
    else:
        return tf.keras.optimizers.Adam(learning_rate)

def get_callbacks(name):
    model_output = f'{name}.h5'
    
    return  [keras.callbacks.ModelCheckpoint(model_output, save_best_only=True, monitor="val_loss"),
                keras.callbacks.ReduceLROnPlateau( monitor="val_loss", factor=0.2, patience=3, min_lr=0.0001),
                keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1)]
    
def compile_and_fit(model, name,optimizer, epochs=30, batch_size=256, learning_rate=0.01,shuffle=False):
    optimizer = get_optimizer(optimizer, learning_rate)

    model.compile(optimizer=optimizer,
                  loss=tf.keras.losses.sparse_categorical_crossentropy,
                  metrics=['accuracy'])
    model.summary()
    history = model.fit(train_ds,
                      epochs=epochs,
                      validation_data=val_ds,
                      callbacks=get_callbacks(name),
                      verbose=1, batch_size=batch_size,shuffle=shuffle)
    return history

# %% [markdown]
# # Experiment 1 : (Raw Signal) --> CNN Model

# %%
X_train, Y_train = load_data('/kaggle/input/raw-ecg/Raw_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/raw-ecg/Raw_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/raw-ecg/Raw_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 1000),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 1000),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 1000),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 1000)', 'Shape of Batched Dataset (256,)']

# %%
#HYPER_PARAMETERS
BATCH_SIZE = 256
num_classes = 5
LEARNING_RATE = 0.01
input_shape = X_train.shape[1:]
activation_fn = 'relu'

# %%
# Create the Conv1D model
def create_conv1d_model(input_shape):
    model = Sequential()
    model.add(Conv1D(256, 3, activation='relu', input_shape=input_shape, kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Conv1D(256, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(Dropout(0.2))
    model.add(Conv1D(256, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Conv1D(128, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(Conv1D(128, 3, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(GlobalAveragePooling1D())
    model.add(Dense(1024, activation='relu', kernel_regularizer=l2(0.01)))
    model.add(Dense(num_classes, activation='softmax'))
    return model

# %%
conv1d_model = create_conv1d_model(input_shape)

# %%
history = compile_and_fit(conv1d_model,"expt1_conv1d_model",optimizer='adam',epochs=20,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 10, 256)           768256
#
#  batch_normalization (BatchN  (None, 10, 256)          1024
#  ormalization)
#
#  conv1d_1 (Conv1D)           (None, 8, 256)            196864
#
#  batch_normalization_1 (Batc  (None, 8, 256)           1024
#  hNormalization)
#
#  max_pooling1d (MaxPooling1D  (None, 8, 256)           0
#  )
#
#  dropout (Dropout)           (None, 8, 256)            0
#
#  conv1d_2 (Conv1D)           (None, 6, 256)            196864
#
#  batch_normalization_2 (Batc  (None, 6, 256)           1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 6, 256)            0
#
#  conv1d_3 (Conv1D)           (None, 4, 128)            98432
#
#  batch_normalization_3 (Batc  (None, 4, 128)           512
#  hNormalization)
#
#  conv1d_4 (Conv1D)           (None, 2, 128)            49280
#
#  batch_normalization_4 (Batc  (None, 2, 128)           512
#  hNormalization)
#
#  max_pooling1d_1 (MaxPooling  (None, 2, 128)           0
#  1D)
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 1024)              132096
#
#  dense_1 (Dense)             (None, 5)                 5125
#
# =================================================================
# Total params: 1,451,013
# Trainable params: 1,448,965
# Non-trainable params: 2,048
# _________________________________________________________________
# Epoch 1/20
# 44/44 [==============================] - 13s 211ms/step - loss: 11.1484 - accuracy: 0.5501 - val_loss: 7.7326 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/20
# 44/44 [==============================] - 9s 207ms/step - loss: 5.6774 - accuracy: 0.5708 - val_loss: 4.4373 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/20
# 44/44 [==============================] - 9s 204ms/step - loss: 3.2784 - accuracy: 0.5708 - val_loss: 2.9531 - val_accuracy: 0.1536 - lr: 0.0010
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.13832335329341316
# Precision of the Model is 0.019133350066334397
# Recall of the Model is 0.13832335329341316
# F1 Score of the Model is 0.03361672236799415

# %% [markdown]
# # Experiment 2: LSTM Model

# %%
# Create the LSTM model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, return_sequences=True, input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(LSTM(64,return_sequences=True,))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(LSTM(64,return_sequences=True,))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    model.add(MaxPooling1D(3, strides=1, padding='same'))
    model.add(Flatten())
    model.add(Dense(num_classes, activation='sigmoid'))
    return model

# %%
lstm_model = create_lstm_model(input_shape)

# %%
history = compile_and_fit(lstm_model,"expt2_lstm_model",optimizer='adam',epochs=25,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 12, 64)            272640
#
#  batch_normalization_5 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 12, 64)            0
#
#  lstm_1 (LSTM)               (None, 12, 64)            33024
#
#  batch_normalization_6 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 12, 64)            0
#
#  lstm_2 (LSTM)               (None, 12, 64)            33024
#
#  batch_normalization_7 (Batc  (None, 12, 64)           256
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 12, 64)            0
#
#  max_pooling1d_2 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  flatten (Flatten)           (None, 768)               0
#
#  dense_2 (Dense)             (None, 5)                 3845
#
# =================================================================
# Total params: 343,301
# Trainable params: 342,917
# Non-trainable params: 384
# _________________________________________________________________
# Epoch 1/25
# 44/44 [==============================] - 13s 152ms/step - loss: 1.7473 - accuracy: 0.4327 - val_loss: 1.6542 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 2/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.5155 - accuracy: 0.4664 - val_loss: 1.7920 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 3/25
# 44/44 [==============================] - 5s 117ms/step - loss: 1.4339 - accuracy: 0.4911 - val_loss: 1.7093 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 4/25
# 44/44 [==============================] - 5s 115ms/step - loss: 1.4032 - accuracy: 0.5067 - val_loss: 1.6444 - val_accuracy: 0.1530 - lr: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 5s 124ms/step - loss: 1.3721 - accuracy: 0.5216 - val_loss: 1.4965 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 5s 116ms/step - loss: 1.3546 - accuracy: 0.5289 - val_loss: 1.4070 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.3385 - accuracy: 0.5384 - val_loss: 1.4967 - val_accuracy: 0.1162 - lr: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 5s 119ms/step - loss: 1.3330 - accuracy: 0.5407 - val_loss: 1.3907 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/25
# 44/44 [==============================] - 5s 119ms/step - loss: 1.3272 - accuracy: 0.5438 - val_loss: 1.3717 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 10/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.3207 - accuracy: 0.5482 - val_loss: 1.3752 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 11/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.3170 - accuracy: 0.5498 - val_loss: 1.3340 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 12/25
# 44/44 [==============================] - 5s 116ms/step - loss: 1.3155 - accuracy: 0.5526 - val_loss: 1.3408 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 13/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.3191 - accuracy: 0.5518 - val_loss: 1.3320 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 14/25
# 44/44 [==============================] - 6s 128ms/step - loss: 1.3090 - accuracy: 0.5536 - val_loss: 1.3269 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 15/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.3114 - accuracy: 0.5534 - val_loss: 1.3321 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 16/25
# 44/44 [==============================] - 5s 123ms/step - loss: 1.3052 - accuracy: 0.5541 - val_loss: 1.3037 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 17/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.2960 - accuracy: 0.5542 - val_loss: 1.3267 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 18/25
# 44/44 [==============================] - 5s 124ms/step - loss: 1.2942 - accuracy: 0.5551 - val_loss: 1.3872 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 19/25
# 44/44 [==============================] - 5s 115ms/step - loss: 1.2911 - accuracy: 0.5551 - val_loss: 1.4975 - val_accuracy: 0.5534 - lr: 0.0010
# Epoch 20/25
# 44/44 [==============================] - 5s 118ms/step - loss: 1.2856 - accuracy: 0.5552 - val_loss: 1.4391 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 21/25
# 44/44 [==============================] - 5s 122ms/step - loss: 1.2791 - accuracy: 0.5553 - val_loss: 1.3582 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 22/25
# 44/44 [==============================] - 5s 120ms/step - loss: 1.2761 - accuracy: 0.5553 - val_loss: 1.3095 - val_accuracy: 0.5544 - lr: 2.0000e-04
# Epoch 23/25
# 44/44 [==============================] - 5s 121ms/step - loss: 1.2786 - accuracy: 0.5553 - val_loss: 1.2848 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 24/25
# 44/44 [==============================] - 6s 128ms/step - loss: 1.2760 - accuracy: 0.5553 - val_loss: 1.2833 - val_accuracy: 0.5544 - lr: 1.0000e-04
# Epoch 25/25
# 44/44 [==============================] - 5s 125ms/step - loss: 1.2752 - accuracy: 0.5553 - val_loss: 1.2865 - val_accuracy: 0.5544 - lr: 1.0000e-04

# %%
display_output(lstm_model, history)
# Out:
# 53/53 [==============================] - 2s 12ms/step
# 53/53 [==============================] - 1s 11ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5401197604790419
# Precision of the Model is 0.2917293556599376
# Recall of the Model is 0.5401197604790419
# F1 Score of the Model is 0.3788398320000745

# %% [markdown]
# # Experiment 3: 1D CNN MHA (Multi Head Attention) model

# %%
def create_conv1d_mha_model(input_shape, regularizer=0.01):
    inputs = Input(shape=input_shape)
    
    # Convolutional layers
    conv1 = Conv1D(32, 1, activation='relu')(inputs)
    batch_norm1 =  BatchNormalization()(conv1)
    conv2 = Conv1D(64, 1, activation='relu')(batch_norm1)
    batch_norm2 =  BatchNormalization()(conv2)
    max_pooling1 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm2)
    dropout1 = Dropout(0.2)(max_pooling1)
    conv3 = Conv1D(128, 1, activation='relu')(dropout1)
    batch_norm3 =  BatchNormalization()(conv3)
    dropout2 = Dropout(0.3)(batch_norm3)
    conv4 = Conv1D(128, 1, activation='relu')(dropout2)
    batch_norm4 =  BatchNormalization()(conv4)
    max_pooling2 =  MaxPooling1D(3, strides=1, padding='same')(batch_norm4)
    conv5 = Conv1D(512, 1, activation='relu')(max_pooling2)
    batch_norm5 =  BatchNormalization()(conv5)
    conv6 = Conv1D(512, 1, activation='relu')(batch_norm5)
    # Multi-head attention
    attention = MultiHeadAttention(num_heads=5, key_dim=3)(conv6, conv6)
    attention = LayerNormalization(epsilon=1e-6)(attention)
    
    # Concatenate attention output and conv3
    concat = Concatenate()([conv6, attention])
    
    # Global average pooling
    pool = tf.keras.layers.GlobalAveragePooling1D()(concat)
    
    dropout3 = Dropout(0.3)(pool)
    
     # Dense layers
    dense1 = Dense(256, activation='relu')(dropout3)
    dropout4 = Dropout(0.5)(dense1)
    dense2 = Dense(128, activation='relu')(dropout4)
    # Dense layer
    dense = Dense(num_classes, activation='softmax',
                  kernel_regularizer=regularizers.l2(regularizer))(dense2) 
    
    # Create model
    model = Model(inputs=inputs, outputs=dense)
    
    return model

# %%
conv1d_mha_model= create_conv1d_mha_model(input_shape)

# %%
history = compile_and_fit(conv1d_mha_model,"expt3_cnn_mha_model",optimizer='adam',epochs=25,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 12, 1000)]   0           []
#
#  conv1d_5 (Conv1D)              (None, 12, 32)       32032       ['input_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 12, 32)      128         ['conv1d_5[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 12, 64)       2112        ['batch_normalization_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 12, 64)      256         ['conv1d_6[0][0]']
#  rmalization)
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 12, 64)      0           ['batch_normalization_9[0][0]']
#
#  dropout_5 (Dropout)            (None, 12, 64)       0           ['max_pooling1d_3[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 12, 128)      8320        ['dropout_5[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 12, 128)     512         ['conv1d_7[0][0]']
#  ormalization)
#
#  dropout_6 (Dropout)            (None, 12, 128)      0           ['batch_normalization_10[0][0]']
#
#  conv1d_8 (Conv1D)              (None, 12, 128)      16512       ['dropout_6[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 12, 128)     512         ['conv1d_8[0][0]']
#  ormalization)
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 12, 128)     0           ['batch_normalization_11[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 12, 512)      66048       ['max_pooling1d_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 12, 512)     2048        ['conv1d_9[0][0]']
#  ormalization)
#
#  conv1d_10 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_12[0][0]']
#
#  multi_head_attention (MultiHea  (None, 12, 512)     31277       ['conv1d_10[0][0]',
#  dAttention)                                                      'conv1d_10[0][0]']
#
#  layer_normalization (LayerNorm  (None, 12, 512)     1024        ['multi_head_attention[0][0]']
#  alization)
#
#  concatenate (Concatenate)      (None, 12, 1024)     0           ['conv1d_10[0][0]',
#                                                                   'layer_normalization[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 1024)        0           ['concatenate[0][0]']
#  obalAveragePooling1D)
#
#  dropout_7 (Dropout)            (None, 1024)         0           ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dense_3 (Dense)                (None, 256)          262400      ['dropout_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 256)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 128)          32896       ['dropout_8[0][0]']
#
#  dense_5 (Dense)                (None, 5)            645         ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 719,378
# Trainable params: 717,650
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/25
# 44/44 [==============================] - 17s 278ms/step - loss: 1.4196 - accuracy: 0.5366 - val_loss: 1.3826 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/25
# 44/44 [==============================] - 12s 269ms/step - loss: 1.3133 - accuracy: 0.5697 - val_loss: 1.3808 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/25
# 44/44 [==============================] - 12s 272ms/step - loss: 1.2833 - accuracy: 0.5758 - val_loss: 1.3807 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/25
# 44/44 [==============================] - 12s 264ms/step - loss: 1.2618 - accuracy: 0.5795 - val_loss: 1.3758 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/25
# 44/44 [==============================] - 12s 269ms/step - loss: 1.2452 - accuracy: 0.5793 - val_loss: 1.3646 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/25
# 44/44 [==============================] - 12s 271ms/step - loss: 1.2242 - accuracy: 0.5798 - val_loss: 1.3577 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/25
# 44/44 [==============================] - 12s 265ms/step - loss: 1.2159 - accuracy: 0.5800 - val_loss: 1.3373 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/25
# 44/44 [==============================] - 11s 261ms/step - loss: 1.1996 - accuracy: 0.5811 - val_loss: 1.7740 - val_accuracy: 0.1338 - lr: 0.0010
# Epoch 9/25
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.13832335329341316
# Precision of the Model is 0.01917928848185981
# Recall of the Model is 0.13832335329341316
# F1 Score of the Model is 0.03368760633714122

# %% [markdown]
# # Experiment 4: VGG Model

# %%
# Define the VGGNet-based model
def create_vggnet_model(input_shape, num_classes):
    model = Sequential()

    # Block 1
    model.add(Conv1D(64, kernel_size=1, activation='relu', padding='same', input_shape=input_shape))
    model.add(Conv1D(64, kernel_size=1, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=1, strides=1))

    # Block 2
    model.add(Conv1D(128, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(128, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=1))

    # Block 3
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(256, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Block 4
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Block 5
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(Conv1D(512, kernel_size=2, activation='relu', padding='same'))
    model.add(MaxPooling1D(pool_size=2, strides=2))

    # Fully connected layers
    model.add(Flatten())
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(4096, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
vggnet_model = create_vggnet_model(input_shape, 5)

# %%
history = compile_and_fit(vggnet_model,"expt4_vggnet_model",optimizer='adam',epochs=15,batch_size=256,learning_rate=0.001)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (None, 12, 64)            64064
#
#  conv1d_12 (Conv1D)          (None, 12, 64)            4160
#
#  max_pooling1d_5 (MaxPooling  (None, 12, 64)           0
#  1D)
#
#  conv1d_13 (Conv1D)          (None, 12, 128)           16512
#
#  conv1d_14 (Conv1D)          (None, 12, 128)           32896
#
#  max_pooling1d_6 (MaxPooling  (None, 11, 128)          0
#  1D)
#
#  conv1d_15 (Conv1D)          (None, 11, 256)           65792
#
#  conv1d_16 (Conv1D)          (None, 11, 256)           131328
#
#  conv1d_17 (Conv1D)          (None, 11, 256)           131328
#
#  max_pooling1d_7 (MaxPooling  (None, 5, 256)           0
#  1D)
#
#  conv1d_18 (Conv1D)          (None, 5, 512)            262656
#
#  conv1d_19 (Conv1D)          (None, 5, 512)            524800
#
#  conv1d_20 (Conv1D)          (None, 5, 512)            524800
#
#  max_pooling1d_8 (MaxPooling  (None, 2, 512)           0
#  1D)
#
#  conv1d_21 (Conv1D)          (None, 2, 512)            524800
#
#  conv1d_22 (Conv1D)          (None, 2, 512)            524800
#
#  conv1d_23 (Conv1D)          (None, 2, 512)            524800
#
#  max_pooling1d_9 (MaxPooling  (None, 1, 512)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 4096)              2101248
#
#  dense_7 (Dense)             (None, 4096)              16781312
#
#  dense_8 (Dense)             (None, 5)                 20485
#
# =================================================================
# Total params: 22,235,781
# Trainable params: 22,235,781
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 44/44 [==============================] - 79s 2s/step - loss: 1.4331 - accuracy: 0.5553 - val_loss: 1.2944 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2702 - accuracy: 0.5553 - val_loss: 1.2822 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/15
# 44/44 [==============================] - 75s 2s/step - loss: 1.2660 - accuracy: 0.5553 - val_loss: 1.2840 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/15
# 44/44 [==============================] - 75s 2s/step - loss: 1.2664 - accuracy: 0.5553 - val_loss: 1.2842 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/15
# 44/44 [==============================] - 73s 2s/step - loss: 1.2656 - accuracy: 0.5553 - val_loss: 1.2818 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2650 - accuracy: 0.5553 - val_loss: 1.2806 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2649 - accuracy: 0.5553 - val_loss: 1.2784 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 8/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2650 - accuracy: 0.5553 - val_loss: 1.2775 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 9/15
# 44/44 [==============================] - 72s 2s/step - loss: 1.2649 - accuracy: 0.5553 - val_loss: 1.2751 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 10/15
# 44/44 [==============================] - 73s 2s/step - loss: 1.2645 - accuracy: 0.5553 - val_loss: 1.2743 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 11/15
# 44/44 [==============================] - 72s 2s/step - loss: 1.2638 - accuracy: 0.5553 - val_loss: 1.2731 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 12/15
# 44/44 [==============================] - 74s 2s/step - loss: 1.2632 - accuracy: 0.5553 - val_loss: 1.2730 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 13/15
# 44/44 [==============================] - 71s 2s/step - loss: 1.2633 - accuracy: 0.5553 - val_loss: 1.2723 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 14/15
# 44/44 [==============================] - 71s 2s/step - loss: 1.2629 - accuracy: 0.5553 - val_loss: 1.2716 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 15/15
# 44/44 [==============================] - 71s 2s/step - loss: 1.2626 - accuracy: 0.5553 - val_loss: 1.2712 - val_accuracy: 0.5544 - lr: 0.0010

# %%
display_output(vggnet_model, history)
# Out:
# 53/53 [==============================] - 2s 30ms/step
# 53/53 [==============================] - 2s 36ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5401197604790419
# Precision of the Model is 0.2917293556599376
# Recall of the Model is 0.5401197604790419
# F1 Score of the Model is 0.3788398320000745

# %% [markdown]
# # Experiment 5 - # 1-D CNN, Multi-head attention (Feature Selection) 188 features

# %%
X_train, Y_train = load_data('/kaggle/input/ecg-features-train/X_Features_train.npz', 'train', "X", "Y")
X_val, Y_val = load_data('/kaggle/input/ecg-features-fe/X_Features_val.npz','val', "X", "Y")
X_test, Y_test = load_data('/kaggle/input/ecg-features-fe/X_Features_test.npz','test', "X","Y")
# Out:
# Shape of X-train and Y_train : (11297, 12, 188),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 188),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 188),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 188)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 188)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape)

# %%
history = compile_and_fit(conv1d_mha_model,"expt5_cnn_mha_model",optimizer='adam',epochs=100,batch_size=256,learning_rate=0.001)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 12, 188)]    0           []
#
#  conv1d_24 (Conv1D)             (None, 12, 32)       6048        ['input_2[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 12, 32)      128         ['conv1d_24[0][0]']
#  ormalization)
#
#  conv1d_25 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 12, 64)      256         ['conv1d_25[0][0]']
#  ormalization)
#
#  max_pooling1d_10 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_14[0][0]']
#  )
#
#  dropout_9 (Dropout)            (None, 12, 64)       0           ['max_pooling1d_10[0][0]']
#
#  conv1d_26 (Conv1D)             (None, 12, 128)      8320        ['dropout_9[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 12, 128)     512         ['conv1d_26[0][0]']
#  ormalization)
#
#  dropout_10 (Dropout)           (None, 12, 128)      0           ['batch_normalization_15[0][0]']
#
#  conv1d_27 (Conv1D)             (None, 12, 128)      16512       ['dropout_10[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 12, 128)     512         ['conv1d_27[0][0]']
#  ormalization)
#
#  max_pooling1d_11 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_16[0][0]']
#  )
#
#  conv1d_28 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_11[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 12, 512)     2048        ['conv1d_28[0][0]']
#  ormalization)
#
#  conv1d_29 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_17[0][0]']
#
#  multi_head_attention_1 (MultiH  (None, 12, 512)     31277       ['conv1d_29[0][0]',
#  eadAttention)                                                    'conv1d_29[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_1[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 12, 1024)     0           ['conv1d_29[0][0]',
#                                                                   'layer_normalization_1[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 1024)        0           ['concatenate_1[0][0]']
#  obalAveragePooling1D)
#
#  dropout_11 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  dense_9 (Dense)                (None, 256)          262400      ['dropout_11[0][0]']
#
#  dropout_12 (Dropout)           (None, 256)          0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 128)          32896       ['dropout_12[0][0]']
#
#  dense_11 (Dense)               (None, 5)            645         ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 693,394
# Trainable params: 691,666
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 18s 302ms/step - loss: 1.4389 - accuracy: 0.5274 - val_loss: 1.4371 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 12s 278ms/step - loss: 1.3542 - accuracy: 0.5652 - val_loss: 1.3994 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] - 11s 247ms/step - loss: 1.3174 - accuracy: 0.5720 - val_loss: 1.3908 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/100
# 44/44 [==============================] - 11s 245ms/step - loss: 1.3016 - accuracy: 0.5742 - val_loss: 1.3759 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/100
# 44/44 [==============================] - 11s 252ms/step - loss: 1.2843 - accuracy: 0.5766 - val_loss: 1.3416 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/100
# 44/44 [==============================] - 11s 246ms/step - loss: 1.2641 - accuracy: 0.5801 - val_loss: 1.3285 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.2572 - accuracy: 0.5771 - val_loss: 1.3253 - val_accuracy: 0.5550 - lr: 0.0010
# Epoch 8/100
# 44/44 [==============================] - 11s 249ms/step - loss: 1.2369 - accuracy: 0.5855 - val_loss: 1.3304 - val_accuracy: 0.5609 - lr: 0.0010
# Epoch 9/100
# 44/44 [==============================] - 11s 244ms/step - loss: 1.2238 - accuracy: 0.5879 - val_loss: 1.3347 - val_accuracy: 0.5671 - lr: 0.0010
# Epoch 10/100
# 44/44 [==============================] - 11s 256ms/step - loss: 1.2176 - accuracy: 0.5900 - val_loss: 1.2967 - val_accuracy: 0.5729 - lr: 0.0010
# Epoch 11/100
# 44/44 [==============================] - 11s 248ms/step - loss: 1.2017 - accuracy: 0.5953 - val_loss: 1.2852 - val_accuracy: 0.5794 - lr: 0.0010
# Epoch 12/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.1893 - accuracy: 0.6025 - val_loss: 1.2966 - val_accuracy: 0.5807 - lr: 0.0010
# Epoch 13/100
# 44/44 [==============================] - 11s 245ms/step - loss: 1.1905 - accuracy: 0.5990 - val_loss: 1.2682 - val_accuracy: 0.5876 - lr: 0.0010
# 44/44 [==============================] - 11s 240ms/step - loss: 1.0084 - accuracy: 0.6568 - val_loss: 1.1862 - val_accuracy: 0.5928 - lr: 1.0000e-04
# Epoch 98/100
# 44/44 [==============================] - 11s 252ms/step - loss: 1.0055 - accuracy: 0.6569 - val_loss: 1.1816 - val_accuracy: 0.5938 - lr: 1.0000e-04
# Epoch 99/100
# 44/44 [==============================] - 11s 243ms/step - loss: 1.0071 - accuracy: 0.6601 - val_loss: 1.1872 - val_accuracy: 0.5911 - lr: 1.0000e-04
# Epoch 100/100
# 44/44 [==============================] - 11s 249ms/step - loss: 1.0023 - accuracy: 0.6583 - val_loss: 1.1851 - val_accuracy: 0.5934 - lr: 1.0000e-04

# %%
display_output(conv1d_mha_model,history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.5790419161676646
# Precision of the Model is 0.5351118887368776
# Recall of the Model is 0.5790419161676646
# F1 Score of the Model is 0.4875825747465665

# %% [markdown]
# # Experiment 5.1 - # 1-D CNN, Multi-head attention (Feature Selection + Additional Features)

# %%
X_train, Y_train = load_data('/kaggle/input/fe-all/X_AllFeatures_train.npz', 'train')
X_val, Y_val = load_data('/kaggle/input/fe-all/X_AllFeatures_val.npz','val')
X_test, Y_test = load_data('/kaggle/input/fe-all/X_AllFeatures_test.npz','test')
# Out:
# Shape of X-train and Y_train : (11297, 12, 365),  (11297,)
# Shape of X-val and Y_val : (3268, 12, 365),  (3268,)
# Shape of X-test and Y_test : (1670, 12, 365),  (1670,)

# %%
train_ds = create_dataset(X_train, Y_train)
val_ds = create_dataset(X_val, Y_val)
# Out:
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']
# ['Shape of Batched Dataset (256, 12, 365)', 'Shape of Batched Dataset (256,)']

# %%
input_shape = X_train.shape[1:]
conv1d_mha_model= create_conv1d_mha_model(input_shape, 0.001)

# %%
history = compile_and_fit(conv1d_mha_model,"expt5.1_cnn_mha_model",optimizer='adam',epochs=100,batch_size=128,learning_rate=0.001)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 12, 365)]    0           []
#
#  conv1d_30 (Conv1D)             (None, 12, 32)       11712       ['input_3[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 12, 32)      128         ['conv1d_30[0][0]']
#  ormalization)
#
#  conv1d_31 (Conv1D)             (None, 12, 64)       2112        ['batch_normalization_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 12, 64)      256         ['conv1d_31[0][0]']
#  ormalization)
#
#  max_pooling1d_12 (MaxPooling1D  (None, 12, 64)      0           ['batch_normalization_19[0][0]']
#  )
#
#  dropout_13 (Dropout)           (None, 12, 64)       0           ['max_pooling1d_12[0][0]']
#
#  conv1d_32 (Conv1D)             (None, 12, 128)      8320        ['dropout_13[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 12, 128)     512         ['conv1d_32[0][0]']
#  ormalization)
#
#  dropout_14 (Dropout)           (None, 12, 128)      0           ['batch_normalization_20[0][0]']
#
#  conv1d_33 (Conv1D)             (None, 12, 128)      16512       ['dropout_14[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 12, 128)     512         ['conv1d_33[0][0]']
#  ormalization)
#
#  max_pooling1d_13 (MaxPooling1D  (None, 12, 128)     0           ['batch_normalization_21[0][0]']
#  )
#
#  conv1d_34 (Conv1D)             (None, 12, 512)      66048       ['max_pooling1d_13[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 12, 512)     2048        ['conv1d_34[0][0]']
#  ormalization)
#
#  conv1d_35 (Conv1D)             (None, 12, 512)      262656      ['batch_normalization_22[0][0]']
#
#  multi_head_attention_2 (MultiH  (None, 12, 512)     31277       ['conv1d_35[0][0]',
#  eadAttention)                                                    'conv1d_35[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 12, 512)     1024        ['multi_head_attention_2[0][0]']
#  rmalization)
#
#  concatenate_2 (Concatenate)    (None, 12, 1024)     0           ['conv1d_35[0][0]',
#                                                                   'layer_normalization_2[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 1024)        0           ['concatenate_2[0][0]']
#  obalAveragePooling1D)
#
#  dropout_15 (Dropout)           (None, 1024)         0           ['global_average_pooling1d_3[0][0
#                                                                  ]']
#
#  dense_12 (Dense)               (None, 256)          262400      ['dropout_15[0][0]']
#
#  dropout_16 (Dropout)           (None, 256)          0           ['dense_12[0][0]']
#
#  dense_13 (Dense)               (None, 128)          32896       ['dropout_16[0][0]']
#
#  dense_14 (Dense)               (None, 5)            645         ['dense_13[0][0]']
#
# ==================================================================================================
# Total params: 699,058
# Trainable params: 697,330
# Non-trainable params: 1,728
# __________________________________________________________________________________________________
# Epoch 1/100
# 44/44 [==============================] - 16s 262ms/step - loss: 1.3652 - accuracy: 0.5264 - val_loss: 1.4001 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 2/100
# 44/44 [==============================] - 11s 260ms/step - loss: 1.2625 - accuracy: 0.5533 - val_loss: 1.3628 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 3/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.2394 - accuracy: 0.5584 - val_loss: 1.3299 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 4/100
# 44/44 [==============================] - 12s 275ms/step - loss: 1.2219 - accuracy: 0.5629 - val_loss: 1.3203 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 5/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.1885 - accuracy: 0.5740 - val_loss: 1.3416 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 6/100
# 44/44 [==============================] - 12s 262ms/step - loss: 1.1772 - accuracy: 0.5700 - val_loss: 1.3351 - val_accuracy: 0.5544 - lr: 0.0010
# Epoch 7/100
# 44/44 [==============================] - 11s 253ms/step - loss: 1.1732 - accuracy: 0.5708 - val_loss: 1.3086 - val_accuracy: 0.5553 - lr: 0.0010
# Epoch 8/100
# 44/44 [==============================] - 11s 257ms/step - loss: 1.1500 - accuracy: 0.5795 - val_loss: 1.2963 - val_accuracy: 0.5583 - lr: 0.0010
# Epoch 9/100
# 44/44 [==============================] - 11s 248ms/step - loss: 1.1384 - accuracy: 0.5789 - val_loss: 1.2411 - val_accuracy: 0.5622 - lr: 0.0010
# Epoch 10/100
# Epoch 27/100
# 44/44 [==============================] - 11s 250ms/step - loss: 0.9737 - accuracy: 0.6380 - val_loss: 1.1093 - val_accuracy: 0.5951 - lr: 1.0000e-04
# Epoch 28/100
# 44/44 [==============================] - 11s 248ms/step - loss: 0.9696 - accuracy: 0.6365 - val_loss: 1.1076 - val_accuracy: 0.5954 - lr: 1.0000e-04
# Epoch 29/100
# 44/44 [==============================] - 11s 257ms/step - loss: 0.9608 - accuracy: 0.6424 - val_loss: 1.1098 - val_accuracy: 0.5993 - lr: 1.0000e-04
# Epoch 30/100
# 44/44 [==============================] - 11s 256ms/step - loss: 0.9685 - accuracy: 0.6387 - val_loss: 1.1053 - val_accuracy: 0.6012 - lr: 1.0000e-04
# Epoch 31/100
# 44/44 [==============================] - 11s 260ms/step - loss: 0.9607 - accuracy: 0.6396 - val_loss: 1.1085 - val_accuracy: 0.6003 - lr: 1.0000e-04
# Epoch 32/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9583 - accuracy: 0.6428 - val_loss: 1.1089 - val_accuracy: 0.5999 - lr: 1.0000e-04
# Epoch 33/100
# 44/44 [==============================] - 11s 250ms/step - loss: 0.9548 - accuracy: 0.6404 - val_loss: 1.1109 - val_accuracy: 0.6003 - lr: 1.0000e-04
# Epoch 34/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.9555 - accuracy: 0.6402 - val_loss: 1.1112 - val_accuracy: 0.6009 - lr: 1.0000e-04
# Epoch 35/100
# 44/44 [==============================] - 11s 259ms/step - loss: 0.9517 - accuracy: 0.6423 - val_loss: 1.1083 - val_accuracy: 0.6012 - lr: 1.0000e-04
# Epoch 36/100
# 44/44 [==============================] - 12s 270ms/step - loss: 0.9545 - accuracy: 0.6422 - val_loss: 1.1036 - val_accuracy: 0.6016 - lr: 1.0000e-04
# Epoch 37/100
# 44/44 [==============================] - 11s 261ms/step - loss: 0.9501 - accuracy: 0.6440 - val_loss: 1.1097 - val_accuracy: 0.6012 - lr: 1.0000e-04
# Epoch 38/100
# 44/44 [==============================] - 11s 259ms/step - loss: 0.9469 - accuracy: 0.6484 - val_loss: 1.1096 - val_accuracy: 0.6032 - lr: 1.0000e-04
# Epoch 39/100
# 44/44 [==============================] - 11s 252ms/step - loss: 0.9511 - accuracy: 0.6463 - val_loss: 1.1063 - val_accuracy: 0.6012 - lr: 1.0000e-04
# Epoch 40/100
# 44/44 [==============================] - 11s 250ms/step - loss: 0.9446 - accuracy: 0.6479 - val_loss: 1.1087 - val_accuracy: 0.6025 - lr: 1.0000e-04
# Epoch 41/100
# 44/44 [==============================] - 11s 247ms/step - loss: 0.9390 - accuracy: 0.6483 - val_loss: 1.1097 - val_accuracy: 0.5983 - lr: 1.0000e-04
# Epoch 42/100
# 44/44 [==============================] - 11s 247ms/step - loss: 0.9347 - accuracy: 0.6562 - val_loss: 1.1075 - val_accuracy: 0.6029 - lr: 1.0000e-04
# Epoch 43/100
# Epoch 60/100
# 44/44 [==============================] - 11s 253ms/step - loss: 0.9161 - accuracy: 0.6623 - val_loss: 1.1165 - val_accuracy: 0.6035 - lr: 1.0000e-04
# Epoch 61/100
# 44/44 [==============================] - 11s 249ms/step - loss: 0.9147 - accuracy: 0.6619 - val_loss: 1.1116 - val_accuracy: 0.6045 - lr: 1.0000e-04
# Epoch 62/100
# 44/44 [==============================] - 11s 258ms/step - loss: 0.9096 - accuracy: 0.6602 - val_loss: 1.1127 - val_accuracy: 0.6071 - lr: 1.0000e-04
# Epoch 63/100
# 44/44 [==============================] - 11s 258ms/step - loss: 0.9082 - accuracy: 0.6669 - val_loss: 1.1156 - val_accuracy: 0.6051 - lr: 1.0000e-04
# Epoch 64/100
# 44/44 [==============================] - 11s 261ms/step - loss: 0.9077 - accuracy: 0.6650 - val_loss: 1.1182 - val_accuracy: 0.6051 - lr: 1.0000e-04
# Epoch 65/100
# 44/44 [==============================] - 11s 255ms/step - loss: 0.9015 - accuracy: 0.6652 - val_loss: 1.1226 - val_accuracy: 0.6061 - lr: 1.0000e-04
# Epoch 66/100
# 44/44 [==============================] - 11s 257ms/step - loss: 0.8972 - accuracy: 0.6658 - val_loss: 1.1205 - val_accuracy: 0.6058 - lr: 1.0000e-04
# Epoch 67/100
# 44/44 [==============================] - 12s 264ms/step - loss: 0.8943 - accuracy: 0.6711 - val_loss: 1.1330 - val_accuracy: 0.6042 - lr: 1.0000e-04
# Epoch 68/100
# 44/44 [==============================] - 12s 266ms/step - loss: 0.8962 - accuracy: 0.6701 - val_loss: 1.1337 - val_accuracy: 0.6035 - lr: 1.0000e-04
# Epoch 69/100
# 44/44 [==============================] - 12s 268ms/step - loss: 0.8933 - accuracy: 0.6724 - val_loss: 1.1250 - val_accuracy: 0.6071 - lr: 1.0000e-04
# Epoch 70/100
# 44/44 [==============================] - 12s 263ms/step - loss: 0.8943 - accuracy: 0.6715 - val_loss: 1.1342 - val_accuracy: 0.6035 - lr: 1.0000e-04
# Epoch 71/100
# 44/44 [==============================] - 11s 260ms/step - loss: 0.8926 - accuracy: 0.6706 - val_loss: 1.1351 - val_accuracy: 0.6035 - lr: 1.0000e-04
# Epoch 72/100
# 44/44 [==============================] - 11s 259ms/step - loss: 0.8866 - accuracy: 0.6753 - val_loss: 1.1394 - val_accuracy: 0.6025 - lr: 1.0000e-04
# Epoch 73/100
# 44/44 [==============================] - 11s 254ms/step - loss: 0.8914 - accuracy: 0.6724 - val_loss: 1.1342 - val_accuracy: 0.6038 - lr: 1.0000e-04
# Epoch 73: early stopping

# %%
display_output(conv1d_mha_model, history)
# Out:
# 53/53 [==============================] - 1s 10ms/step
# 53/53 [==============================] - 1s 10ms/step
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Accuracy of the Model is  0.581437125748503
# Precision of the Model is 0.5434977478044578
# Recall of the Model is 0.581437125748503
# F1 Score of the Model is 0.48578755773271803

# %% [markdown]
# # Experiment 6 - # 1-D CNN, Multi-head attention + Ensemble Classifier (Raw Signal + Feature Selection)
